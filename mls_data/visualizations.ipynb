# %%
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import numpy as np

# %%
# database_path = 'postgresql://postgres:postgres@localhost/Employees'
# engine = create_engine("sqlite:///{database_path}")
# conn = engine.connect()

engine = create_engine('postgresql+psycopg2://postgres:postgres@localhost/mls_db')
connection = engine.connect()

# %%
highest_player_salary = pd.read_sql('SELECT * FROM sorted_highest_paid_player_by_club', connection)
highest_player_salary
# Out:
#     club_id                    club          first             last  \
# 0       9.0               LA Galaxy         Zlatan      Ibrahimovic
# 1      23.0              Toronto FC        Michael          Bradley
# 2      10.0                    LAFC         Carlos             Vela
# 3       2.0            Chicago Fire        Bastian   Schweinsteiger
# 4      12.0         Montreal Impact        Ignacio           Piatti
# 5       5.0               DC United          Wayne           Rooney
# 6       1.0          Atlanta United          Josef         Martinez
# 7      18.0        Portland Timbers      Sebastian           Blanco
# 8      21.0     Seattle Sounders FC        Nicolas          Lodeiro
# 9      16.0         Orlando City SC            NaN             Nani
# 10      3.0         Colorado Rapids            Tim           Howard
# 11     13.0  New England Revolution         Carles              Gil
# 12     17.0      Philadelphia Union          Marco           Fabian
# ...

# %%
percent_wins = pd.read_sql('SELECT * FROM percent_wins', connection)
percent_wins
# Out:
#     id                    Club  % Wins
# 0   10                    LAFC   0.712
# 1    1          Atlanta United   0.563
# 2   14        New York City FC   0.621
# 3   19          Real Salt Lake   0.508
# 4   17      Philadelphia Union   0.525
# 5   21     Seattle Sounders FC   0.533
# 6    9               LA Galaxy   0.492
# 7   11        Minnesota United   0.500
# 8   18        Portland Timbers   0.459
# 9   15      New York Red Bulls   0.452
# 10  23              Toronto FC   0.456
# 11   5               DC United   0.456
# 12   7               FC Dallas   0.441
# 13  20    San Jose Earthquakes   0.413
# 14   8          Houston Dynamo   0.375
# 15  12         Montreal Impact   0.381
# 16   3         Colorado Rapids   0.387
# 17  13  New England Revolution   0.393
# 18  22    Sporting Kansas City   0.333
# 19   4           Columbus Crew   0.333
# 20   2            Chicago Fire   0.357
# 21  16         Orlando City SC   0.310
# 22  24     Vancouver Whitecaps   0.276
# ...

# %%
goals = pd.read_sql('SELECT * FROM player_goals', connection)
goals

# goal_stats = pd.read_sql('SELECT * FROM stats', connection)
# goal_stats
# Out:
#      club_id                    club   first         last  Total Goals
# 0       10.0                    LAFC  Carlos         Vela         34.0
# 1        9.0               LA Galaxy  Zlatan  Ibrahimović         30.0
# 2        1.0          Atlanta United   Josef     Martínez         27.0
# 3       10.0                    LAFC   Diego        Rossi         16.0
# 4       14.0        New York City FC   Héber         None         15.0
# ..       ...                     ...     ...          ...          ...
# 641     18.0        Portland Timbers   Zarek     Valentin          0.0
# 642      8.0          Houston Dynamo   Aljaž       Struna          0.0
# 643      3.0         Colorado Rapids    Axel      Sjöberg          0.0
# 644     13.0  New England Revolution   Tajon     Buchanan          0.0
# 645     17.0      Philadelphia Union  Carlos      Coronel          0.0
#
# [646 rows x 5 columns]

# %%
team_payroll = pd.read_sql('SELECT * FROM team_payroll', connection)
team_payroll
# Out:
#     club_id                    club  Roster Payroll
# 0      23.0              Toronto FC     24267066.18
# 1       9.0               LA Galaxy     19636979.69
# 2       2.0            Chicago Fire     17114980.99
# 3      10.0                    LAFC     13769951.28
# 4      21.0     Seattle Sounders FC     13678414.29
# 5      12.0         Montreal Impact     13152273.71
# 6       1.0          Atlanta United     12957118.93
# 7      16.0         Orlando City SC     12573226.29
# 8      18.0        Portland Timbers     12553916.46
# 9      22.0    Sporting Kansas City     12070675.60
# 10     19.0          Real Salt Lake     11117788.60
# 11     11.0        Minnesota United     10632485.61
# 12     20.0    San Jose Earthquakes     10619980.43
# 13      4.0           Columbus Crew     10614613.28
# 14     13.0  New England Revolution     10608217.28
# 15     14.0        New York City FC     10415586.82
# 16      5.0               DC United     10195277.26
# ...

# %%
salaries = pd.read_sql('SELECT * FROM salaries', connection)
salaries
# Out:
#       id  club_id     first          last                  club position  \
# 0      1     17.0   Brenden      Aaronson    Philadelphia Union      M-F
# 1      2     21.0      Saad  Abdul-Salaam   Seattle Sounders FC        D
# 2      3      3.0     Lalas      Abubakar       Colorado Rapids        D
# 3      4      4.0     David         Accam         Columbus Crew      M-F
# 4      5      3.0    Kellyn        Acosta       Colorado Rapids      D-M
# ..   ...      ...       ...           ...                   ...      ...
# 697  699     10.0    Walker     Zimmerman                  LAFC        D
# 698  700      7.0      Kyle        Zobeck             FC Dallas       GK
# 699  701      9.0     Ethan         Zubak             LA Galaxy        F
# 700  702     22.0    Graham          Zusi  Sporting Kansas City      D-M
# 701  703      9.0  Jonathan    dos Santos             LA Galaxy        M
#
#      base_salary  guaranteed_compensation
# 0       70000.08                 98309.48
# ...

# %%
salary_goal = pd.concat([salaries, goals ], axis=1, join='inner')
salary_goal
millionaires =  salary_goal.loc[(salary_goal['Total Goals'] >= 1)&(salary_goal['guaranteed_compensation'] >= 1000000)]
millionaires
# millionaires.groupby('club').agg({'guaranteed_compensation':sum})
# Out:
#       id  club_id      first          last                    club position  \
# 3      4      4.0      David         Accam           Columbus Crew      M-F
# 9     10      6.0    Fanendo           Adi           FC Cincinnati        F
# 10    11     24.0        Ali         Adnan     Vancouver Whitecaps        D
# 19    20      9.0     Romain  Alessandrini               LA Galaxy      M-F
# 24    25     23.0       Jozy      Altidore              Toronto FC        F
# 60    61      1.0   Ezequiel         Barco          Atlanta United      M-F
# 71    72     17.0  Alejandro        Bedoya      Philadelphia Union        M
# 88    89     18.0  Sebastian        Blanco        Portland Timbers      M-F
# 96    97     13.0    Gustavo           Bou  New England Revolution        F
# 98    99     23.0    Michael       Bradley              Toronto FC        M
# 189  191     16.0        Dom         Dwyer         Orlando City SC        F
# ...

# %%
millionaires['position'].value_counts()
# Out:
# D      94
# M-F    77
# M      63
# F      45
# GK     31
# D-M    27
# Name: position, dtype: int64
