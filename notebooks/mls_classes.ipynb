# %%
# Dependencies
import sys 
import os
import psycopg2
# ----------------------------------
# Run my other notebook so I can use my datafames/my variables
# %run mls_data.ipynb 
# %run mls_salary_data.ipynb

# Import SQL Alchemy
import sqlalchemy
from sqlalchemy import create_engine, inspect, func
# Import and establish Base for which classes will be constructed 

from sqlalchemy.orm import relationship
# Import modules to declare columns and column data types
from sqlalchemy import Column, Integer, String, Float, ForeignKey

# Create a relationship between foreign keys and primary keys:
from sqlalchemy.orm import relationship
# Import and establish Base for which classes will be constructed 
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# Session is a temporary binding to our DB
from sqlalchemy.orm import Session
import numpy
from psycopg2.extensions import register_adapter, AsIs

# %%
engine = create_engine('postgresql+psycopg2://postgres:postgres@localhost/mls_db')
# Establish Connection
conn = engine.connect()

# %%
# clear out the db
Base.metadata.drop_all(engine)

# %%
# Define tables: 
# For all possible integers that might be used for calculations in sequel, I'd suggest making them into floats
# SQL will have issues creating decimal values without the use of extra functions
# Table names, columns, and schemas should all be lowercase to prevent the required usage of " " around column names, table, schemas will cause overall issues
# All foreign keys must be addressed in primary key table and named accordingly with other tables
# Create teams and salary classes for tables in sql


# Club	Conference	Ranking	Matches Played	Wins	Draws	Losses	Total Points
class Clubs(Base):
    __tablename__ = 'clubs'
    id = Column(Integer, primary_key=True, index=True)
    club = Column(String(50), unique = True)
    conference = Column(String(50))
    ranking = Column(Integer)
    matches_played = Column(Float)
    wins = Column(Float)
    draws = Column(Float)
    losses = Column(Float)
    total_points = Column(Float)
    def __repr__(self): 
        return "Club(id ={self.id},"\
    "club = '{self.club}',"\
    "conference = '{self.conference}',"\
    "ranking = {self.ranking},"\
    "matches_played = {self.matches_played},"\
    "wins = {self.wins},"\
    "draws = {self.draws},"\
    "losses = {self.losses},"\
    "total_points = {self.total_points})".format(self=self)
    goals_child = relationship('Goals')
    xgoals_child = relationship('Xgoals')
    mvp_child = relationship('Mvp')
    players_child = relationship('Players')
    salary_child = relationship('Salary')
    
# Goals For	Goals Against	Goal Differential	Total Points
class Goals(Base):
    __tablename__ = 'goals'
    id = Column(Integer, primary_key=True, index=True)
    clubs_id = Column(Integer, ForeignKey('clubs.id'), index=True)
    goals_for = Column(Float)
    goals_against = Column(Float)
    goal_differential = Column(Float)
    def __repr__(self): 
        return "Goals(clubs_id = {self.clubs_id},"\
    "goals_for = {self.goals_for},"\
    "goals_against = {self.goals_against},"\
    "goal_differential = {self.goal_differential})".format(self=self)
    
# Expected Goals	Expected Goals Allowed	Expected Goals Differiential	Expected Goals Differiential/ 90 (mins)  
class Xgoals(Base):
    __tablename__ = 'xgoals'
    id = Column(Integer, primary_key=True, index=True)
    clubs_id = Column(Integer, ForeignKey('clubs.id'), index=True)
    expected_goals = Column(Float)
    expected_allowed = Column(Float)
    expected_goals_differiential = Column(Float)
    expected_goals_differiential_mins = Column(Float)
    def __repr__(self):
        return "Expected(clubs_id = '{self.clubs_id}',"\
    "expected_goals = {self.expected_goals},"\
    "expected_allowed = {self.expected_allowed},"\
    "expected_goals_differiential = {self.expected_goals_differiential},"\
    "expected_goals_differiential_mins = {self.expected_goals_differiential_mins})".format(self=self)
    
# Spectators	Top Team Scorer	Goalkeeper
class Mvp(Base):
    __tablename__ = 'mvp'
    id = Column(Integer, primary_key=True, index=True)
    clubs_id = Column(Integer, ForeignKey('clubs.id'), index=True)
    spectators = Column(Float)
    top_team_scorer = Column(String(50))
    goalkeeper = Column(String(50))
    def __repr__(self):
        return "Mvp(clubs_id = '{self.clubs_id}',"\
    "spectators = {self.spectators},"\
    "top_team_Scorer = '{self.top_team_scorer}',"\
    "goalkeeper = '{self.goalkeeper}')".format(self=self)   
    
class Salary(Base):
    __tablename__ = 'salary'
    id = Column(Integer, primary_key=True)
    clubs_id = Column(Integer, ForeignKey('clubs.id'))
    first = Column(String(50))
    last = Column(String(50))
    club = Column(String(50))
    position = Column(String(50))
    base_salary = Column(Float)
    guaranteed_compensation = Column(Float)
    def __repr__(self):
        return "Salary(clubs_id = {self.clubs_id},"\
    "first = '{self.first}',"\
    "last = '{self.last}',"\
    "club = '{self.club}',"\
    "position = '{self.position}',"\
    "base_salary = {self.base_salary},"\
    "guaranteed_compensation = {self.guaranteed_compensation})".format(self=self)   
    
class Players(Base):
    __tablename__ = 'players'
    id = Column(Integer, primary_key = True)
    clubs_id = Column(Integer, ForeignKey('clubs.id'))
    first = Column(String(50))
    last = Column(String(50))
    nation = Column(String(50))
    position = Column(String(50))
    club = Column(String(50))
    age = Column(Float)
    born = Column(Float)
    mp = Column(Float)
    starts = Column(Float)
    goals = Column(Float)
    assists = Column(Float)
    pk = Column(Float)
    pkatt = Column(Float)
    yellow_card = Column(Float)
    red_card = Column(Float)
    def __repr__(self):
        return "Player(clubs_id = {self.clubs_id},"\
    "first = '{self.first}',"\
    "last = '{self.last}',"\
    "nation = '{self.nation}',"\
    "position = '{self.position}',"\
    "club = '{self.club}',"\
    "age = {self.age},"\
    "born = {self.born},"\
    "mp = {self.mp},"\
    "starts = {self.starts},"\
    "goals = {self.goals},"\
    "assists = {self.assists},"\
    "pk = '{self.pk}',"\
    "pkatt = {self.pkatt},"\
    "yellow_card = {self.yellow_card},"\
    "red_card = {self.red_card})".format(self=self)
    
class Teams(Base):
    __tablename__ = 'teams'
    id = Column(Integer, primary_key=True)
    club = Column(String(50))
    def __repr__(self):
        return "Teams(id = {self.id},"\
    "club = '{self.club}')".format(self=self)

# %%
# Create Session
# ----------------------------------
session = Session(bind=engine)

# %%
# Create tables within the database
Base.metadata.create_all(conn)

# %%
# # Create a Session Object to Connect to DB:
# The issue with function is my lack of expertise, the errors are less likely to show to fix my classes and mapping. 
# def run_my_sesions():
#     # Create Session
#     # ----------------------------------
#     session = Session(bind=engine)
#     try:
#         session.bulk_insert_mappings(League, league_df.T.to_dict(orient="records"))
#         session.bulk_insert_mappings(Goals, actual_stats_df.T.to_dict(orient="records"))
#         session.bulk_insert_mappings(Expected, expected_stats_df.T.to_dict(orient="records"))
#         session.bulk_insert_mappings(MVP, mvp_df.T.to_dict(orient="records"))
#         session.commit()
#     except:
#         session.rollback()
#         raise
#     finally:
#         session.close()
# run_my_sesions()

# %%
# To loop over all members of the Classes attribute and type; to ensure less mistakes:
def Classify(objects, arg):
    caste = objects.capitalize()
    members = [attr for attr in dir(objects) if not callable(getattr(objects,attr)) and attr.startswith("____")]
    print(members)    
Classify("clubs", "Base")
# Out:
# []

# %%
for row in league_df.iterrows():
    clubs = Clubs(id= row[0],  club = row[1]['club'], conference = row[1]['conference'], ranking = row[1]['ranking'],
                     matches_played = row[1]['matches_played'], wins = row[1]['wins'], draws = row[1]['draws'], losses = row[1]['losses'], total_points = row[1]['total_points'])
    session.add(clubs)
    print(clubs)
# Out:
# Club(id =14,club = 'New York City FC',conference = 'Eastern',ranking = 1,matches_played = 34,wins = 18,draws = 10,losses = 6,total_points = 64)
# Club(id =1,club = 'Atlanta United',conference = 'Eastern',ranking = 2,matches_played = 34,wins = 18,draws = 4,losses = 12,total_points = 58)
# Club(id =17,club = 'Philadelphia Union',conference = 'Eastern',ranking = 3,matches_played = 34,wins = 16,draws = 7,losses = 11,total_points = 55)
# Club(id =23,club = 'Toronto FC',conference = 'Eastern',ranking = 4,matches_played = 34,wins = 13,draws = 11,losses = 10,total_points = 50)
# Club(id =5,club = 'DC United',conference = 'Eastern',ranking = 5,matches_played = 34,wins = 13,draws = 11,losses = 10,total_points = 50)
# Club(id =15,club = 'New York Red Bulls',conference = 'Eastern',ranking = 6,matches_played = 34,wins = 14,draws = 6,losses = 14,total_points = 48)
# Club(id =13,club = 'New England Revolution',conference = 'Eastern',ranking = 7,matches_played = 34,wins = 11,draws = 12,losses = 11,total_points = 45)
# Club(id =2,club = 'Chicago Fire',conference = 'Eastern',ranking = 8,matches_played = 34,wins = 10,draws = 12,losses = 12,total_points = 42)
# Club(id =12,club = 'Montreal Impact',conference = 'Eastern',ranking = 9,matches_played = 34,wins = 12,draws = 5,losses = 17,total_points = 41)
# Club(id =4,club = 'Columbus Crew',conference = 'Eastern',ranking = 10,matches_played = 34,wins = 10,draws = 8,losses = 16,total_points = 38)
# Club(id =16,club = 'Orlando City SC',conference = 'Eastern',ranking = 11,matches_played = 34,wins = 9,draws = 10,losses = 15,total_points = 37)
# Club(id =6,club = 'FC Cincinnati',conference = 'Eastern',ranking = 12,matches_played = 34,wins = 6,draws = 6,losses = 22,total_points = 24)
# Club(id =10,club = 'LAFC',conference = 'Western',ranking = 1,matches_played = 34,wins = 21,draws = 9,losses = 4,total_points = 72)
# Club(id =21,club = 'Seattle Sounders FC',conference = 'Western',ranking = 2,matches_played = 34,wins = 16,draws = 8,losses = 10,total_points = 56)
# Club(id =19,club = 'Real Salt Lake',conference = 'Western',ranking = 3,matches_played = 34,wins = 16,draws = 5,losses = 13,total_points = 53)
# Club(id =11,club = 'Minnesota United',conference = 'Western',ranking = 4,matches_played = 34,wins = 15,draws = 8,losses = 11,total_points = 53)
# Club(id =9,club = 'LA Galaxy',conference = 'Western',ranking = 5,matches_played = 34,wins = 16,draws = 3,losses = 15,total_points = 51)
# Club(id =18,club = 'Portland Timbers',conference = 'Western',ranking = 6,matches_played = 34,wins = 14,draws = 7,losses = 13,total_points = 49)
# Club(id =7,club = 'FC Dallas',conference = 'Western',ranking = 7,matches_played = 34,wins = 13,draws = 9,losses = 12,total_points = 48)
# Club(id =20,club = 'San Jose Earthquakes',conference = 'Western',ranking = 8,matches_played = 34,wins = 13,draws = 5,losses = 16,total_points = 44)
# Club(id =3,club = 'Colorado Rapids',conference = 'Western',ranking = 9,matches_played = 34,wins = 12,draws = 6,losses = 16,total_points = 42)
# Club(id =8,club = 'Houston Dynamo',conference = 'Western',ranking = 10,matches_played = 34,wins = 12,draws = 4,losses = 18,total_points = 40)
# Club(id =22,club = 'Sporting Kansas City',conference = 'Western',ranking = 11,matches_played = 34,wins = 10,draws = 8,losses = 16,total_points = 38)
# Club(id =24,club = 'Vancouver Whitecaps',conference = 'Western',ranking = 12,matches_played = 34,wins = 8,draws = 10,losses = 16,total_points = 34)

# %%
def adapt_numpy_int64(numpy_int64):
    """ Adapting numpy.int64 type to SQL-conform int type using psycopg extension, see [1]_ for more info.
    References
    ----------
    .. [1] http://initd.org/psycopg/docs/advanced.html#adapting-new-python-types-to-sql-syntax
    """
    return AsIs(numpy_int64)

register_adapter(numpy.int64, adapt_numpy_int64) 

#Goals For	Goals Against	Goal Differential	Total Points	Goals ID
for row in actual_stats_df.iterrows():
    goals = Goals(clubs_id= row[0], goals_for = row[1]['goals_for'], 
    goals_against = row[1]['goals_against'], goal_differential = row[1]['goal_differential']) 
    session.add(goals)
    register_adapter(numpy.int64, adapt_numpy_int64) 
    print(goals)
# ClubID = row[0],
# Out:
# Goals(clubs_id = 14,goals_for = 63,goals_against = 42,goal_differential = 21)
# Goals(clubs_id = 1,goals_for = 58,goals_against = 43,goal_differential = 15)
# Goals(clubs_id = 17,goals_for = 58,goals_against = 50,goal_differential = 8)
# Goals(clubs_id = 23,goals_for = 57,goals_against = 52,goal_differential = 5)
# Goals(clubs_id = 5,goals_for = 42,goals_against = 38,goal_differential = 4)
# Goals(clubs_id = 15,goals_for = 53,goals_against = 51,goal_differential = 2)
# Goals(clubs_id = 13,goals_for = 50,goals_against = 57,goal_differential = -7)
# Goals(clubs_id = 2,goals_for = 55,goals_against = 47,goal_differential = 8)
# Goals(clubs_id = 12,goals_for = 47,goals_against = 60,goal_differential = -13)
# Goals(clubs_id = 4,goals_for = 39,goals_against = 47,goal_differential = -8)
# Goals(clubs_id = 16,goals_for = 44,goals_against = 52,goal_differential = -8)
# Goals(clubs_id = 6,goals_for = 31,goals_against = 75,goal_differential = -44)
# Goals(clubs_id = 10,goals_for = 85,goals_against = 37,goal_differential = 48)
# Goals(clubs_id = 21,goals_for = 52,goals_against = 49,goal_differential = 3)
# Goals(clubs_id = 19,goals_for = 46,goals_against = 41,goal_differential = 5)
# Goals(clubs_id = 11,goals_for = 52,goals_against = 43,goal_differential = 9)
# Goals(clubs_id = 9,goals_for = 58,goals_against = 59,goal_differential = -1)
# Goals(clubs_id = 18,goals_for = 52,goals_against = 49,goal_differential = 3)
# Goals(clubs_id = 7,goals_for = 54,goals_against = 46,goal_differential = 8)
# Goals(clubs_id = 20,goals_for = 52,goals_against = 55,goal_differential = -3)
# Goals(clubs_id = 3,goals_for = 58,goals_against = 63,goal_differential = -5)
# Goals(clubs_id = 8,goals_for = 49,goals_against = 59,goal_differential = -10)
# Goals(clubs_id = 22,goals_for = 49,goals_against = 67,goal_differential = -18)
# Goals(clubs_id = 24,goals_for = 37,goals_against = 59,goal_differential = -22)

# %%
# Expected Goals	Expected Goals Allowed	Expected Goals Differiential	Expected Goals Differiential/ 90 (mins)
for row in expected_stats_df.iterrows():
    xgoals = Xgoals(clubs_id= row[0], expected_goals = row[1]['expected_goals'], expected_allowed = row[1]['expected_goals_allowed'],
    expected_goals_differiential = row[1]['expected_goals_differiential'], expected_goals_differiential_mins = row[1]['expected_goals_differiential_mins']) 
    session.add(xgoals)
    print(xgoals)
# Out:
# Expected(clubs_id = '14',expected_goals = 51.8,expected_allowed = 44.7,expected_goals_differiential = 7.1,expected_goals_differiential_mins = 0.22)
# Expected(clubs_id = '1',expected_goals = 56.6,expected_allowed = 42.4,expected_goals_differiential = 14.2,expected_goals_differiential_mins = 0.42)
# Expected(clubs_id = '17',expected_goals = 54.9,expected_allowed = 41.8,expected_goals_differiential = 13.1,expected_goals_differiential_mins = 0.39)
# Expected(clubs_id = '23',expected_goals = 48.0,expected_allowed = 49.3,expected_goals_differiential = -1.3,expected_goals_differiential_mins = -0.04)
# Expected(clubs_id = '5',expected_goals = 37.8,expected_allowed = 48.1,expected_goals_differiential = -10.3,expected_goals_differiential_mins = -0.3)
# Expected(clubs_id = '15',expected_goals = 49.9,expected_allowed = 49.7,expected_goals_differiential = 0.2,expected_goals_differiential_mins = 0.01)
# Expected(clubs_id = '13',expected_goals = 44.8,expected_allowed = 54.9,expected_goals_differiential = -10.2,expected_goals_differiential_mins = -0.3)
# Expected(clubs_id = '2',expected_goals = 53.0,expected_allowed = 44.7,expected_goals_differiential = 8.3,expected_goals_differiential_mins = 0.25)
# Expected(clubs_id = '12',expected_goals = 38.4,expected_allowed = 50.0,expected_goals_differiential = -11.6,expected_goals_differiential_mins = -0.34)
# Expected(clubs_id = '4',expected_goals = 37.3,expected_allowed = 41.8,expected_goals_differiential = -4.5,expected_goals_differiential_mins = -0.13)
# Expected(clubs_id = '16',expected_goals = 43.6,expected_allowed = 42.5,expected_goals_differiential = 1.1,expected_goals_differiential_mins = 0.03)
# Expected(clubs_id = '6',expected_goals = 33.1,expected_allowed = 59.3,expected_goals_differiential = -26.3,expected_goals_differiential_mins = -0.77)
# Expected(clubs_id = '10',expected_goals = 77.3,expected_allowed = 36.5,expected_goals_differiential = 40.8,expected_goals_differiential_mins = 1.2)
# Expected(clubs_id = '21',expected_goals = 48.7,expected_allowed = 46.3,expected_goals_differiential = 2.4,expected_goals_differiential_mins = 0.07)
# Expected(clubs_id = '19',expected_goals = 36.5,expected_allowed = 40.4,expected_goals_differiential = -3.9,expected_goals_differiential_mins = -0.11)
# Expected(clubs_id = '11',expected_goals = 52.7,expected_allowed = 44.6,expected_goals_differiential = 8.1,expected_goals_differiential_mins = 0.24)
# Expected(clubs_id = '9',expected_goals = 56.3,expected_allowed = 62.5,expected_goals_differiential = -6.2,expected_goals_differiential_mins = -0.18)
# Expected(clubs_id = '18',expected_goals = 52.8,expected_allowed = 56.2,expected_goals_differiential = -3.4,expected_goals_differiential_mins = -0.1)
# Expected(clubs_id = '7',expected_goals = 49.6,expected_allowed = 43.9,expected_goals_differiential = 5.7,expected_goals_differiential_mins = 0.17)
# Expected(clubs_id = '20',expected_goals = 51.9,expected_allowed = 47.1,expected_goals_differiential = 4.8,expected_goals_differiential_mins = 0.14)
# Expected(clubs_id = '3',expected_goals = 51.1,expected_allowed = 57.0,expected_goals_differiential = -5.9,expected_goals_differiential_mins = -0.17)
# Expected(clubs_id = '8',expected_goals = 47.4,expected_allowed = 50.6,expected_goals_differiential = -3.2,expected_goals_differiential_mins = -0.09)
# Expected(clubs_id = '22',expected_goals = 58.0,expected_allowed = 51.4,expected_goals_differiential = 6.6,expected_goals_differiential_mins = 0.19)
# Expected(clubs_id = '24',expected_goals = 34.4,expected_allowed = 60.3,expected_goals_differiential = -25.9,expected_goals_differiential_mins = -0.76)

# %%
# Spectators	Top Team Scorer	Goalkeeper
for row in mvp_df.iterrows(): 
    mvp = Mvp(clubs_id= row[0], spectators = row[1]['spectators'], top_team_scorer = row[1]['top_team_scorer'],
    goalkeeper = row[1]['goalkeeper']) 
    session.add(mvp)
    print(mvp)
# Out:
# Mvp(clubs_id = '14',spectators = 21107,top_team_Scorer = 'Héber - 15',goalkeeper = 'Sean Johnson')
# Mvp(clubs_id = '1',spectators = 52510,top_team_Scorer = 'Josef Martínez - 27',goalkeeper = 'Brad Guzan')
# Mvp(clubs_id = '17',spectators = 17111,top_team_Scorer = 'Kacper Przybyłko - 15',goalkeeper = 'Andre Blake')
# Mvp(clubs_id = '23',spectators = 25048,top_team_Scorer = 'Alejandro Pozuelo - 12',goalkeeper = 'Quentin Westberg')
# Mvp(clubs_id = '5',spectators = 17744,top_team_Scorer = 'Wayne Rooney - 11',goalkeeper = 'Bill Hamid')
# Mvp(clubs_id = '15',spectators = 17751,top_team_Scorer = 'Daniel Royer - 11',goalkeeper = 'Luis Robles')
# Mvp(clubs_id = '13',spectators = 16737,top_team_Scorer = 'Carles Gil - 10',goalkeeper = 'Matt Turner')
# Mvp(clubs_id = '2',spectators = 12324,top_team_Scorer = 'C.J. Sapong - 13',goalkeeper = 'Kenneth Kronholm')
# Mvp(clubs_id = '12',spectators = 16171,top_team_Scorer = 'Saphir Taïder - 9',goalkeeper = 'Evan Bush')
# Mvp(clubs_id = '4',spectators = 14856,top_team_Scorer = 'Gyasi Zardes - 13',goalkeeper = 'Zack Steffen')
# Mvp(clubs_id = '16',spectators = 22761,top_team_Scorer = 'Nani - 12',goalkeeper = 'Brian Rowe')
# Mvp(clubs_id = '6',spectators = 27336,top_team_Scorer = 'Allan Cruz - 7',goalkeeper = 'Spencer Richey')
# Mvp(clubs_id = '10',spectators = 22251,top_team_Scorer = 'Carlos Vela - 34',goalkeeper = 'Tyler Miller')
# Mvp(clubs_id = '21',spectators = 40247,top_team_Scorer = 'Raúl Ruidíaz - 11',goalkeeper = 'Stefan Frei')
# Mvp(clubs_id = '19',spectators = 18121,top_team_Scorer = 'Albert Rusnák - 10',goalkeeper = 'Nick Rimando')
# Mvp(clubs_id = '11',spectators = 19723,top_team_Scorer = 'Darwin Quintero - 10',goalkeeper = 'Vito Mannone')
# Mvp(clubs_id = '9',spectators = 23205,top_team_Scorer = 'Zlatan Ibrahimović - 30',goalkeeper = 'David Bingham')
# Mvp(clubs_id = '18',spectators = 25218,top_team_Scorer = 'Jeremy Ebobisse, Brian Fernández - 11',goalkeeper = 'Steve Clark')
# Mvp(clubs_id = '7',spectators = 14842,top_team_Scorer = 'Jesus Ferreira - 8',goalkeeper = 'Jesse Gonzalez')
# Mvp(clubs_id = '20',spectators = 18781,top_team_Scorer = 'Chris Wondolowski - 15',goalkeeper = 'Mario Daniel Vega')
# Mvp(clubs_id = '3',spectators = 14284,top_team_Scorer = 'Kei Kamara - 14',goalkeeper = 'Tim Howard')
# Mvp(clubs_id = '8',spectators = 15674,top_team_Scorer = 'Mauro Manotas - 13',goalkeeper = 'Joe Willis')
# Mvp(clubs_id = '22',spectators = 18601,top_team_Scorer = 'Felipe Gutiérrez - 12',goalkeeper = 'Tim Melia')
# Mvp(clubs_id = '24',spectators = 19514,top_team_Scorer = 'Fredy Montero - 8',goalkeeper = 'Maxime Crépeau')

# %%
# teams_id	club
for club in teams_df.iterrows(): 
    teams = Teams(id=club[1]['teams_id'], club=club[1]['club'])
    print(teams)
    session.add(teams)
# Out:
# Teams(id = 1,club = 'Atlanta United')
# Teams(id = 2,club = 'Chicago Fire')
# Teams(id = 3,club = 'Colorado Rapids')
# Teams(id = 4,club = 'Columbus Crew')
# Teams(id = 5,club = 'DC United')
# Teams(id = 6,club = 'FC Cincinnati')
# Teams(id = 7,club = 'FC Dallas')
# Teams(id = 8,club = 'Houston Dynamo')
# Teams(id = 9,club = 'LA Galaxy')
# Teams(id = 10,club = 'LAFC')
# Teams(id = 11,club = 'Minnesota United')
# Teams(id = 12,club = 'Montreal Impact')
# Teams(id = 13,club = 'New England Revolution')
# Teams(id = 14,club = 'New York City FC')
# Teams(id = 15,club = 'New York Red Bulls')
# Teams(id = 16,club = 'Orlando City SC')
# Teams(id = 17,club = 'Philadelphia Union')
# Teams(id = 18,club = 'Portland Timbers')
# Teams(id = 19,club = 'Real Salt Lake')
# Teams(id = 20,club = 'San Jose Earthquakes')
# Teams(id = 21,club = 'Seattle Sounders FC')
# Teams(id = 22,club = 'Sporting Kansas City')
# Teams(id = 23,club = 'Toronto FC')
# Teams(id = 24,club = 'Vancouver Whitecaps')

# %%
# club_id first	last	club	position	base_salary	 guaranteed_compensation
for row in salary_df.iterrows():
    salary = Salary(clubs_id= row[1]['club_id'], first=row[1]['first'],last=row[1]['last'],club=row[1]['club'],
                    position=row[1]['position'],base_salary=row[1]['base_salary'],guaranteed_compensation=row[1]['guaranteed_compensation'])
    print(salary)
    session.add(salary)
# Out:
# Salary(clubs_id = 17,first = 'Brenden',last = 'Aaronson',club = 'Philadelphia Union',position = 'M-F',base_salary = 70000.08,guaranteed_compensation = 98309.48)
# Salary(clubs_id = 21,first = 'Saad',last = 'Abdul-Salaam',club = 'Seattle Sounders FC',position = 'D',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 3,first = 'Lalas',last = 'Abubakar',club = 'Colorado Rapids',position = 'D',base_salary = 135000.0,guaranteed_compensation = 144937.5)
# Salary(clubs_id = 4,first = 'David',last = 'Accam',club = 'Columbus Crew',position = 'M-F',base_salary = 1010004.0,guaranteed_compensation = 1137920.0)
# Salary(clubs_id = 3,first = 'Kellyn',last = 'Acosta',club = 'Colorado Rapids',position = 'D-M',base_salary = 549999.96,guaranteed_compensation = 664999.96)
# Salary(clubs_id = 5,first = 'Luciano',last = 'Acosta',club = 'DC United',position = 'M-F',base_salary = 600000.0,guaranteed_compensation = 702000.0)
# Salary(clubs_id = 7,first = 'Bryan',last = 'Acosta',club = 'FC Dallas',position = 'M',base_salary = 600000.0,guaranteed_compensation = 650000.0)
# Salary(clubs_id = 16,first = 'Danilo',last = 'Acosta',club = 'Orlando City SC',position = 'D',base_salary = 110000.04,guaranteed_compensation = 110000.04)
# Salary(clubs_id = 1,first = 'Mohammed "Mo"',last = 'Adams',club = 'Atlanta United',position = 'M',base_salary = 99999.96,guaranteed_compensation = 134999.96)
# Salary(clubs_id = 6,first = 'Fanendo',last = 'Adi',club = 'FC Cincinnati',position = 'F',base_salary = 1360008.0,guaranteed_compensation = 1965008.0)
# Salary(clubs_id = 24,first = 'Ali',last = 'Adnan',club = 'Vancouver Whitecaps',position = 'D',base_salary = 1200000.0,guaranteed_compensation = 1277499.9)
# Salary(clubs_id = 20,first = 'Francois',last = 'Affolter',club = 'San Jose Earthquakes',position = 'D',base_salary = 249999.96,guaranteed_compensation = 281999.96)
# Salary(clubs_id = 4,first = 'Harrison',last = 'Afful',club = 'Columbus Crew',position = 'D',base_salary = 288099.96,guaranteed_compensation = 363799.96)
# Salary(clubs_id = 13,first = 'Juan',last = 'Agudelo',club = 'New England Revolution',position = 'F',base_salary = 574999.92,guaranteed_compensation = 604999.92)
# Salary(clubs_id = 20,first = 'Jacob',last = 'Akanyirige',club = 'San Jose Earthquakes',position = 'D',base_salary = 62225.04,guaranteed_compensation = 64225.04)
# Salary(clubs_id = 16,first = 'Tesho',last = 'Akindele',club = 'Orlando City SC',position = 'F',base_salary = 150000.0,guaranteed_compensation = 150000.0)
# Salary(clubs_id = 23,first = 'Ayo',last = 'Akinola',club = 'Toronto FC',position = 'F',base_salary = 56256.0,guaranteed_compensation = 124256.0)
# Salary(clubs_id = 6,first = 'Fatai',last = 'Alashe',club = 'FC Cincinnati',position = 'D-M',base_salary = 189999.96,guaranteed_compensation = 189999.96)
# Salary(clubs_id = 6,first = 'Nazmi',last = 'Albadawi',club = 'FC Cincinnati',position = 'M-F',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 9,first = 'Romain',last = 'Alessandrini',club = 'LA Galaxy',position = 'M-F',base_salary = 1610004.0,guaranteed_compensation = 1940004.0)
# Salary(clubs_id = 7,first = 'Eric',last = 'Alexander',club = 'FC Dallas',position = 'M',base_salary = 270000.0,guaranteed_compensation = 270000.0)
# Salary(clubs_id = 17,first = 'RJ',last = 'Allen',club = 'Philadelphia Union',position = 'D',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 19,first = 'Jordan',last = 'Allen',club = 'Real Salt Lake',position = 'M-F',base_salary = 237999.96,guaranteed_compensation = 237999.96)
# Salary(clubs_id = 11,first = 'Osvaldo',last = 'Alonso',club = 'Minnesota United',position = 'D-M',base_salary = 650000.04,guaranteed_compensation = 697500.04)
# Salary(clubs_id = 23,first = 'Jozy',last = 'Altidore',club = 'Toronto FC',position = 'F',base_salary = 4891250.04,guaranteed_compensation = 6332250.04)
# Salary(clubs_id = 9,first = 'Favio',last = 'Alvarez',club = 'LA Galaxy',position = 'M-F',base_salary = 525000.0,guaranteed_compensation = 586250.0)
# Salary(clubs_id = 9,first = 'Efrain',last = 'Alvarez',club = 'LA Galaxy',position = 'M-F',base_salary = 70872.0,guaranteed_compensation = 75605.8)
# Salary(clubs_id = 17,first = 'Fabinho',last = 'Alves',club = 'Philadelphia Union',position = 'D',base_salary = 120000.0,guaranteed_compensation = 120000.0)
# Salary(clubs_id = 5,first = 'Quincy',last = 'Amarikwa',club = 'DC United',position = 'F',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 6,first = 'Frankie',last = 'Amaya',club = 'FC Cincinnati',position = 'M-F',base_salary = 110000.04,guaranteed_compensation = 172000.04)
# Salary(clubs_id = 1,first = 'Mikey',last = 'Ambrose',club = 'Atlanta United',position = 'D',base_salary = 72351.6,guaranteed_compensation = 72351.6)
# Salary(clubs_id = 7,first = 'Edwin',last = 'Anane-Gyasi',club = 'FC Dallas',position = 'M-F',base_salary = 570000.0,guaranteed_compensation = 719225.0)
# Salary(clubs_id = 3,first = 'Sebastian',last = 'Anderson',club = 'Colorado Rapids',position = 'D',base_salary = 56250.0,guaranteed_compensation = 80916.67)
# Salary(clubs_id = 13,first = 'Isaac',last = 'Angking',club = 'New England Revolution',position = 'M-F',base_salary = 70250.04,guaranteed_compensation = 75250.04)
# Salary(clubs_id = 13,first = 'Jalil',last = 'Anibaba',club = 'New England Revolution',position = 'D',base_salary = 101250.0,guaranteed_compensation = 101250.0)
# Salary(clubs_id = 9,first = 'Uriel',last = 'Antuna',club = 'LA Galaxy',position = 'M-F',base_salary = 420000.0,guaranteed_compensation = 420000.0)
# Salary(clubs_id = 7,first = 'Pablo',last = 'Aranguiz',club = 'FC Dallas',position = 'M-F',base_salary = 406666.68,guaranteed_compensation = 466666.68)
# Salary(clubs_id = 9,first = 'Julian',last = 'Araujo',club = 'LA Galaxy',position = 'D',base_salary = 80000.04,guaranteed_compensation = 86250.04)
# Salary(clubs_id = 14,first = 'Heber',last = 'Araujo dos Santos',club = 'New York City FC',position = 'F',base_salary = 785000.04,guaranteed_compensation = 788750.04)
# Salary(clubs_id = 24,first = 'Joaquín',last = 'Ardaiz',club = 'Vancouver Whitecaps',position = 'F',base_salary = 272727.12,guaranteed_compensation = 272727.12)
# Salary(clubs_id = 9,first = 'Hugo',last = 'Arellano',club = 'LA Galaxy',position = 'D',base_salary = 82500.0,guaranteed_compensation = 90073.75)
# Salary(clubs_id = 4,first = 'Luis',last = 'Argudo',club = 'Columbus Crew',position = 'M-F',base_salary = 57225.0,guaranteed_compensation = 57225.0)
# Salary(clubs_id = 21,first = 'Xavier',last = 'Arreaga',club = 'Seattle Sounders FC',position = 'D',base_salary = 393600.0,guaranteed_compensation = 500850.0)
# Salary(clubs_id = 19,first = 'Luis',last = 'Arriaga',club = 'Real Salt Lake',position = 'M',base_salary = 56250.0,guaranteed_compensation = 56250.0)
# Salary(clubs_id = 5,first = 'Paul',last = 'Arriola',club = 'DC United',position = 'M',base_salary = 675000.0,guaranteed_compensation = 707000.0)
# Salary(clubs_id = 4,first = 'nan',last = 'Artur',club = 'Columbus Crew',position = 'D-M',base_salary = 360000.0,guaranteed_compensation = 411633.33)
# Salary(clubs_id = 16,first = 'Carlos',last = 'Ascues',club = 'Orlando City SC',position = 'D-M',base_salary = 420000.0,guaranteed_compensation = 451500.0)
# Salary(clubs_id = 18,first = 'Dairon',last = 'Asprilla',club = 'Portland Timbers',position = 'M-F',base_salary = 200000.04,guaranteed_compensation = 213750.04)
# Salary(clubs_id = 18,first = 'Jeff',last = 'Attinella',club = 'Portland Timbers',position = 'GK',base_salary = 174999.96,guaranteed_compensation = 187249.96)
# Salary(clubs_id = 7,first = 'Francis',last = 'Atuahene',club = 'FC Dallas',position = 'M-F',base_salary = 135000.0,guaranteed_compensation = 179000.0)
# Salary(clubs_id = 10,first = 'Eduard',last = 'Atuesta',club = 'LAFC',position = 'D-M',base_salary = 474999.96,guaranteed_compensation = 492999.96)
# Salary(clubs_id = 23,first = 'nan',last = 'Auro',club = 'Toronto FC',position = 'D',base_salary = 225000.0,guaranteed_compensation = 276666.67)
# Salary(clubs_id = 2,first = 'Micheal',last = 'Azira',club = 'Chicago Fire',position = 'D-M',base_salary = 140000.04,guaranteed_compensation = 146625.04)
# Salary(clubs_id = 7,first = 'Dominique',last = 'Badji',club = 'FC Dallas',position = 'F',base_salary = 200000.04,guaranteed_compensation = 206250.04)
# Salary(clubs_id = 24,first = 'Thelonius',last = 'Bair',club = 'Vancouver Whitecaps',position = 'F',base_salary = 56250.0,guaranteed_compensation = 76250.0)
# Salary(clubs_id = 19,first = 'Corey',last = 'Baird',club = 'Real Salt Lake',position = 'F',base_salary = 70008.0,guaranteed_compensation = 70008.0)
# Salary(clubs_id = 23,first = 'Jon',last = 'Bakero',club = 'Toronto FC',position = 'F',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 24,first = 'Michael',last = 'Baldisimo',club = 'Vancouver Whitecaps',position = 'D-M',base_salary = 56250.0,guaranteed_compensation = 83012.8)
# Salary(clubs_id = 24,first = 'Alhassane "Lass"',last = 'Bangoura',club = 'Vancouver Whitecaps',position = 'M-F',base_salary = 99999.96,guaranteed_compensation = 99999.96)
# Salary(clubs_id = 22,first = 'Botond',last = 'Baráth',club = 'Sporting Kansas City',position = 'D',base_salary = 250000.08,guaranteed_compensation = 297333.41)
# Salary(clubs_id = 1,first = 'Ezequiel',last = 'Barco',club = 'Atlanta United',position = 'M-F',base_salary = 1425000.0,guaranteed_compensation = 1425000.0)
# Salary(clubs_id = 15,first = 'Tom',last = 'Barlow',club = 'New York Red Bulls',position = 'F',base_salary = 56250.0,guaranteed_compensation = 56250.0)
# Salary(clubs_id = 14,first = 'Luis',last = 'Barraza',club = 'New York City FC',position = 'GK',base_salary = 56250.0,guaranteed_compensation = 56250.0)
# Salary(clubs_id = 7,first = 'Michael',last = 'Barrios',club = 'FC Dallas',position = 'M-F',base_salary = 500000.04,guaranteed_compensation = 500000.04)
# Salary(clubs_id = 3,first = 'Cole',last = 'Bassett',club = 'Colorado Rapids',position = 'M',base_salary = 75000.0,guaranteed_compensation = 84000.0)
# Salary(clubs_id = 10,first = 'Lamar',last = 'Batista',club = 'LAFC',position = 'D',base_salary = 56250.0,guaranteed_compensation = 56250.0)
# Salary(clubs_id = 12,first = 'Clement',last = 'Bayiha',club = 'Montreal Impact',position = 'M-F',base_salary = 61750.08,guaranteed_compensation = 67125.08)
# Salary(clubs_id = 8,first = 'DaMarcus',last = 'Beasley',club = 'Houston Dynamo',position = 'D',base_salary = 275000.04,guaranteed_compensation = 275000.04)
# Salary(clubs_id = 12,first = 'Jason',last = 'Beaulieu',club = 'Montreal Impact',position = 'GK',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 19,first = 'Kyle',last = 'Beckerman',club = 'Real Salt Lake',position = 'D-M',base_salary = 300000.0,guaranteed_compensation = 325000.0)
# Salary(clubs_id = 14,first = 'Daniel',last = 'Bedoya',club = 'New York City FC',position = 'M-F',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 17,first = 'Alejandro',last = 'Bedoya',club = 'Philadelphia Union',position = 'M',base_salary = 1200000.0,guaranteed_compensation = 1266250.0)
# Salary(clubs_id = 10,first = 'Steven',last = 'Beitashour',club = 'LAFC',position = 'D',base_salary = 275000.04,guaranteed_compensation = 298375.04)
# Salary(clubs_id = 1,first = 'George',last = 'Bello',club = 'Atlanta United',position = 'D',base_salary = 75000.0,guaranteed_compensation = 79000.0)
# Salary(clubs_id = 19,first = 'Tony',last = 'Beltran',club = 'Real Salt Lake',position = 'D',base_salary = 195000.0,guaranteed_compensation = 207000.0)
# Salary(clubs_id = 17,first = 'Joe',last = 'Bendik',club = 'Philadelphia Union',position = 'GK',base_salary = 144000.0,guaranteed_compensation = 144000.0)
# Salary(clubs_id = 23,first = 'Nicolas',last = 'Benezet',club = 'Toronto FC',position = 'M-F',base_salary = 600000.0,guaranteed_compensation = 600000.0)
# Salary(clubs_id = 20,first = 'Matt',last = 'Bersano',club = 'San Jose Earthquakes',position = 'GK',base_salary = 71666.88,guaranteed_compensation = 71666.88)
# Salary(clubs_id = 6,first = 'Leonardo',last = 'Bertone',club = 'FC Cincinnati',position = 'M',base_salary = 450000.0,guaranteed_compensation = 496666.67)
# Salary(clubs_id = 19,first = 'Nick',last = 'Besler',club = 'Real Salt Lake',position = 'M',base_salary = 84999.96,guaranteed_compensation = 84999.96)
# Salary(clubs_id = 22,first = 'Matt',last = 'Besler',club = 'Sporting Kansas City',position = 'D',base_salary = 574997.64,guaranteed_compensation = 674997.64)
# Salary(clubs_id = 15,first = 'Vincent',last = 'Bezecourt',club = 'New York Red Bulls',position = 'M-F',base_salary = 70875.0,guaranteed_compensation = 73295.62)
# Salary(clubs_id = 9,first = 'David',last = 'Bingham',club = 'LA Galaxy',position = 'GK',base_salary = 375000.0,guaranteed_compensation = 375000.0)
# Salary(clubs_id = 8,first = 'Eric',last = 'Bird',club = 'Houston Dynamo',position = 'M',base_salary = 70875.0,guaranteed_compensation = 70875.0)
# Salary(clubs_id = 5,first = 'Steven',last = 'Birnbaum',club = 'DC United',position = 'D',base_salary = 525000.0,guaranteed_compensation = 550000.0)
# Salary(clubs_id = 8,first = 'Jose',last = 'Bizama',club = 'Houston Dynamo',position = 'D',base_salary = 243636.0,guaranteed_compensation = 292427.18)
# Salary(clubs_id = 10,first = 'Tristan',last = 'Blackmon',club = 'LAFC',position = 'D',base_salary = 70250.04,guaranteed_compensation = 72983.95)
# Salary(clubs_id = 17,first = 'Andre',last = 'Blake',club = 'Philadelphia Union',position = 'GK',base_salary = 500004.0,guaranteed_compensation = 550004.0)
# Salary(clubs_id = 18,first = 'Sebastian',last = 'Blanco',club = 'Portland Timbers',position = 'M-F',base_salary = 2740008.0,guaranteed_compensation = 2853341.33)
# Salary(clubs_id = 10,first = 'Latif',last = 'Blessing',club = 'LAFC',position = 'M-F',base_salary = 93750.0,guaranteed_compensation = 110416.67)
# Salary(clubs_id = 3,first = 'Johan',last = 'Blomberg',club = 'Colorado Rapids',position = 'M',base_salary = 250962.0,guaranteed_compensation = 250962.0)
# Salary(clubs_id = 24,first = 'Anthony',last = 'Blondell',club = 'Vancouver Whitecaps',position = 'F',base_salary = 262500.0,guaranteed_compensation = 307703.25)
# Salary(clubs_id = 5,first = 'Emmanuel',last = 'Boateng',club = 'DC United',position = 'M',base_salary = 185000.04,guaranteed_compensation = 185000.04)
# Salary(clubs_id = 6,first = 'Corben',last = 'Bone',club = 'FC Cincinnati',position = 'M',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 23,first = 'Alex',last = 'Bono',club = 'Toronto FC',position = 'GK',base_salary = 350000.04,guaranteed_compensation = 382000.04)
# Salary(clubs_id = 2,first = 'Jonathan',last = 'Bornstein',club = 'Chicago Fire',position = 'D-M',base_salary = 240000.0,guaranteed_compensation = 263200.0)
# Salary(clubs_id = 13,first = 'Gustavo',last = 'Bou',club = 'New England Revolution',position = 'F',base_salary = 2100000.0,guaranteed_compensation = 2100000.0)
# Salary(clubs_id = 11,first = 'Michael',last = 'Boxall',club = 'Minnesota United',position = 'D',base_salary = 300000.0,guaranteed_compensation = 317333.33)
# Salary(clubs_id = 23,first = 'Michael',last = 'Bradley',club = 'Toronto FC',position = 'M',base_salary = 6000000.0,guaranteed_compensation = 6500000.0)
# Salary(clubs_id = 12,first = 'Zachary',last = 'Brault-Guillard',club = 'Montreal Impact',position = 'D',base_salary = 72000.0,guaranteed_compensation = 81000.0)
# Salary(clubs_id = 7,first = 'nan',last = 'Bressan',club = 'FC Dallas',position = 'D',base_salary = 485300.04,guaranteed_compensation = 521931.29)
# Salary(clubs_id = 5,first = 'Frederic',last = 'Brillant',club = 'DC United',position = 'D',base_salary = 264999.96,guaranteed_compensation = 299999.96)
# Salary(clubs_id = 2,first = 'Brandt',last = 'Bronico',club = 'Chicago Fire',position = 'M',base_salary = 84999.96,guaranteed_compensation = 90624.96)
# Salary(clubs_id = 21,first = 'Will',last = 'Bruin',club = 'Seattle Sounders FC',position = 'F',base_salary = 350000.04,guaranteed_compensation = 358333.37)
# Salary(clubs_id = 13,first = 'Tajon',last = 'Buchanan',club = 'New England Revolution',position = 'M-F',base_salary = 90000.0,guaranteed_compensation = 126000.0)
# Salary(clubs_id = 15,first = 'Rece',last = 'Buckmaster',club = 'New York Red Bulls',position = 'D',base_salary = 56250.0,guaranteed_compensation = 56250.0)
# Salary(clubs_id = 13,first = 'Teal',last = 'Bunbury',club = 'New England Revolution',position = 'F',base_salary = 225750.0,guaranteed_compensation = 270750.0)
# Salary(clubs_id = 17,first = 'Cory',last = 'Burke',club = 'Philadelphia Union',position = 'F',base_salary = 75937.56,guaranteed_compensation = 79720.37)
# Salary(clubs_id = 12,first = 'Evan',last = 'Bush',club = 'Montreal Impact',position = 'GK',base_salary = 232000.08,guaranteed_compensation = 294666.75)
# Salary(clubs_id = 22,first = 'Gianluca',last = 'Busio',club = 'Sporting Kansas City',position = 'M-F',base_salary = 90000.0,guaranteed_compensation = 92500.0)
# Salary(clubs_id = 5,first = 'Antonio',last = 'Bustamante',club = 'DC United',position = 'D-M',base_salary = 70250.04,guaranteed_compensation = 74484.83)
# Salary(clubs_id = 21,first = 'Handwalla',last = 'Bwana',club = 'Seattle Sounders FC',position = 'M-F',base_salary = 57225.0,guaranteed_compensation = 57225.0)
# Salary(clubs_id = 13,first = 'Brandon',last = 'Bye',club = 'New England Revolution',position = 'D',base_salary = 59950.08,guaranteed_compensation = 63244.93)
# Salary(clubs_id = 8,first = 'Juan',last = 'Cabezas',club = 'Houston Dynamo',position = 'D-M',base_salary = 268008.0,guaranteed_compensation = 292008.0)
# Salary(clubs_id = 12,first = 'Victor',last = 'Cabrera',club = 'Montreal Impact',position = 'D',base_salary = 150000.0,guaranteed_compensation = 172328.33)
# Salary(clubs_id = 4,first = 'Chris',last = 'Cadden',club = 'Columbus Crew',position = 'M',base_salary = 56250.0,guaranteed_compensation = 56250.0)
# Salary(clubs_id = 13,first = 'Luis',last = 'Caicedo',club = 'New England Revolution',position = 'D-M',base_salary = 300000.0,guaranteed_compensation = 300000.0)
# Salary(clubs_id = 13,first = 'Juan Fernando',last = 'Caicedo',club = 'New England Revolution',position = 'F',base_salary = 500000.04,guaranteed_compensation = 500000.04)
# Salary(clubs_id = 13,first = 'Scott',last = 'Caldwell',club = 'New England Revolution',position = 'M',base_salary = 142312.56,guaranteed_compensation = 153208.56)
# Salary(clubs_id = 14,first = 'Jeff',last = 'Caldwell',club = 'New York City FC',position = 'GK',base_salary = 57225.0,guaranteed_compensation = 57225.0)
# Salary(clubs_id = 14,first = 'Alexander',last = 'Callens',club = 'New York City FC',position = 'D',base_salary = 600000.0,guaranteed_compensation = 664000.0)
# Salary(clubs_id = 20,first = 'Eric',last = 'Calvillo',club = 'San Jose Earthquakes',position = 'M',base_salary = 120000.0,guaranteed_compensation = 136500.0)
# Salary(clubs_id = 2,first = 'Francisco',last = 'Calvo',club = 'Chicago Fire',position = 'D',base_salary = 600000.0,guaranteed_compensation = 672600.0)
# Salary(clubs_id = 12,first = 'Rudy',last = 'Camacho',club = 'Montreal Impact',position = 'D',base_salary = 700000.08,guaranteed_compensation = 749152.58)
# Salary(clubs_id = 21,first = 'Jonathan',last = 'Campbell',club = 'Seattle Sounders FC',position = 'D',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 2,first = 'Diego',last = 'Campos',club = 'Chicago Fire',position = 'D',base_salary = 70250.04,guaranteed_compensation = 72825.04)
# Salary(clubs_id = 7,first = 'Reggie',last = 'Cannon',club = 'FC Dallas',position = 'D',base_salary = 80250.0,guaranteed_compensation = 80250.0)
# Salary(clubs_id = 5,first = 'Russell',last = 'Canouse',club = 'DC United',position = 'M',base_salary = 247500.0,guaranteed_compensation = 247500.0)
# Salary(clubs_id = 1,first = 'Andrew',last = 'Carleton',club = 'Atlanta United',position = 'M-F',base_salary = 84999.96,guaranteed_compensation = 97399.96)
# Salary(clubs_id = 9,first = 'Servando',last = 'Carrasco',club = 'LA Galaxy',position = 'M',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 18,first = 'Julio',last = 'Cascante',club = 'Portland Timbers',position = 'D',base_salary = 170004.0,guaranteed_compensation = 170004.0)
# Salary(clubs_id = 15,first = 'Cristian',last = 'Casseres',club = 'New York Red Bulls',position = 'M',base_salary = 79999.92,guaranteed_compensation = 118749.92)
# Salary(clubs_id = 14,first = 'Valentin',last = 'Castellanos',club = 'New York City FC',position = 'M-F',base_salary = 249999.96,guaranteed_compensation = 274806.41)
# Salary(clubs_id = 13,first = 'Edgar',last = 'Castillo',club = 'New England Revolution',position = 'D',base_salary = 249999.96,guaranteed_compensation = 249999.96)
# Salary(clubs_id = 21,first = 'Emanuel',last = 'Cecchini',club = 'Seattle Sounders FC',position = 'M',base_salary = 648000.0,guaranteed_compensation = 789000.0)
# Salary(clubs_id = 8,first = 'Darwin',last = 'Ceren',club = 'Houston Dynamo',position = 'D-M',base_salary = 300000.0,guaranteed_compensation = 349375.0)
# Salary(clubs_id = 7,first = 'Edwin',last = 'Cerrillo',club = 'FC Dallas',position = 'D-M',base_salary = 70250.04,guaranteed_compensation = 100250.04)
# Salary(clubs_id = 11,first = 'Thomas',last = 'Chacon',club = 'Minnesota United',position = 'M',base_salary = 324999.96,guaranteed_compensation = 336999.96)
# Salary(clubs_id = 14,first = 'Maxime',last = 'Chanot',club = 'New York City FC',position = 'D',base_salary = 650000.04,guaranteed_compensation = 650000.04)
# Salary(clubs_id = 23,first = 'Jay',last = 'Chapman',club = 'Toronto FC',position = 'M',base_salary = 120000.0,guaranteed_compensation = 138500.0)
# Salary(clubs_id = 18,first = 'Diego',last = 'Chara',club = 'Portland Timbers',position = 'M',base_salary = 550000.08,guaranteed_compensation = 568750.08)
# Salary(clubs_id = 24,first = 'Michaell',last = 'Chirinos',club = 'Vancouver Whitecaps',position = 'M',base_salary = 360000.0,guaranteed_compensation = 396875.0)
# Salary(clubs_id = 12,first = 'Mathieu',last = 'Choiniere',club = 'Montreal Impact',position = 'M',base_salary = 80000.04,guaranteed_compensation = 86390.04)
# Salary(clubs_id = 23,first = 'Laurent',last = 'Ciman',club = 'Toronto FC',position = 'D',base_salary = 399999.96,guaranteed_compensation = 435624.96)
# Salary(clubs_id = 4,first = 'Ricardo',last = 'Clark',club = 'Columbus Crew',position = 'M',base_salary = 159999.96,guaranteed_compensation = 159999.96)
# Salary(clubs_id = 18,first = 'Steve',last = 'Clark',club = 'Portland Timbers',position = 'GK',base_salary = 140000.04,guaranteed_compensation = 140000.04)
# Salary(clubs_id = 2,first = 'Stefan',last = 'Cleveland',club = 'Chicago Fire',position = 'GK',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 2,first = 'Elliot',last = 'Collier',club = 'Chicago Fire',position = 'M-F',base_salary = 57225.0,guaranteed_compensation = 57225.0)
# Salary(clubs_id = 17,first = 'Aurelien',last = 'Collin',club = 'Philadelphia Union',position = 'D',base_salary = 175000.08,guaranteed_compensation = 175000.08)
# Salary(clubs_id = 7,first = 'Cristian',last = 'Colman',club = 'FC Dallas',position = 'F',base_salary = 500000.04,guaranteed_compensation = 585000.04)
# Salary(clubs_id = 16,first = 'Josue',last = 'Colman',club = 'Orlando City SC',position = 'M-F',base_salary = 450000.0,guaranteed_compensation = 450000.0)
# Salary(clubs_id = 24,first = 'Simon',last = 'Colyn',club = 'Vancouver Whitecaps',position = 'M-F',base_salary = 56250.0,guaranteed_compensation = 81250.0)
# Salary(clubs_id = 18,first = 'Tomas',last = 'Conechny',club = 'Portland Timbers',position = 'M-F',base_salary = 396000.0,guaranteed_compensation = 396000.0)
# Salary(clubs_id = 24,first = 'Derek',last = 'Cornelius',club = 'Vancouver Whitecaps',position = 'D',base_salary = 99999.96,guaranteed_compensation = 111912.46)
# Salary(clubs_id = 9,first = 'Joe',last = 'Corona',club = 'LA Galaxy',position = 'M',base_salary = 549999.96,guaranteed_compensation = 578499.96)
# Salary(clubs_id = 12,first = 'Jorge',last = 'Corrales',club = 'Montreal Impact',position = 'D',base_salary = 70875.0,guaranteed_compensation = 70875.0)
# Salary(clubs_id = 20,first = 'Cade',last = 'Cowell',club = 'San Jose Earthquakes',position = 'F',base_salary = 57225.0,guaranteed_compensation = 67225.0)
# Salary(clubs_id = 17,first = 'Warren',last = 'Creavalle',club = 'Philadelphia Union',position = 'D-M',base_salary = 162000.0,guaranteed_compensation = 175300.0)
# Salary(clubs_id = 24,first = 'Maxime',last = 'Crepeau',club = 'Vancouver Whitecaps',position = 'GK',base_salary = 90000.0,guaranteed_compensation = 94083.33)
# Salary(clubs_id = 4,first = 'Alex',last = 'Crognale',club = 'Columbus Crew',position = 'D',base_salary = 104504.4,guaranteed_compensation = 104504.4)
# Salary(clubs_id = 13,first = 'Cody',last = 'Cropper',club = 'New England Revolution',position = 'GK',base_salary = 77519.52,guaranteed_compensation = 77519.52)
# Salary(clubs_id = 6,first = 'Allan',last = 'Cruz',club = 'FC Cincinnati',position = 'M',base_salary = 300000.0,guaranteed_compensation = 333125.0)
# Salary(clubs_id = 9,first = 'Emil',last = 'Cuello',club = 'LA Galaxy',position = 'M-F',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 20,first = 'Harold',last = 'Cummings',club = 'San Jose Earthquakes',position = 'D',base_salary = 270000.0,guaranteed_compensation = 320666.67)
# Salary(clubs_id = 6,first = 'Rashawn',last = 'Dally',club = 'FC Cincinnati',position = 'F',base_salary = 56250.0,guaranteed_compensation = 59658.75)
# Salary(clubs_id = 23,first = 'Aidan',last = 'Daniels',club = 'Toronto FC',position = 'M-F',base_salary = 57225.0,guaranteed_compensation = 57225.0)
# Salary(clubs_id = 11,first = 'Abu',last = 'Danladi',club = 'Minnesota United',position = 'F',base_salary = 145000.08,guaranteed_compensation = 180000.08)
# Salary(clubs_id = 15,first = 'Sean',last = 'Davis',club = 'New York Red Bulls',position = 'M',base_salary = 300000.0,guaranteed_compensation = 327500.0)
# Salary(clubs_id = 16,first = 'Alex',last = 'De John',club = 'Orlando City SC',position = 'D',base_salary = 135000.0,guaranteed_compensation = 146614.17)
# Salary(clubs_id = 17,first = 'Jack',last = 'De Vries',club = 'Philadelphia Union',position = 'M-F',base_salary = 90000.0,guaranteed_compensation = 120556.25)
# Salary(clubs_id = 8,first = 'AJ',last = 'DeLaGarza',club = 'Houston Dynamo',position = 'D',base_salary = 249999.96,guaranteed_compensation = 253749.96)
# Salary(clubs_id = 21,first = 'Jordy',last = 'Delem',club = 'Seattle Sounders FC',position = 'D-M',base_salary = 70875.0,guaranteed_compensation = 70875.0)
# Salary(clubs_id = 23,first = 'Nick',last = 'DeLeon',club = 'Toronto FC',position = 'D-M',base_salary = 159528.0,guaranteed_compensation = 175269.67)
# Salary(clubs_id = 23,first = 'Marco "Marky"',last = 'Delgado',club = 'Toronto FC',position = 'M',base_salary = 252999.96,guaranteed_compensation = 252999.96)
# Salary(clubs_id = 6,first = 'Mathieu',last = 'Deplagne',club = 'FC Cincinnati',position = 'D',base_salary = 240000.0,guaranteed_compensation = 254400.0)
# Salary(clubs_id = 8,first = 'Tyler',last = 'Deric',club = 'Houston Dynamo',position = 'GK',base_salary = 159999.96,guaranteed_compensation = 167499.96)
# Salary(clubs_id = 21,first = 'Justin',last = 'Dhillon',club = 'Seattle Sounders FC',position = 'F',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 4,first = 'Luis',last = 'Diaz',club = 'Columbus Crew',position = 'M',base_salary = 300000.0,guaranteed_compensation = 333900.0)
# Salary(clubs_id = 22,first = 'Eric',last = 'Dick',club = 'Sporting Kansas City',position = 'GK',base_salary = 70250.04,guaranteed_compensation = 73699.58)
# Salary(clubs_id = 18,first = 'Claude',last = 'Dielna',club = 'Portland Timbers',position = 'D',base_salary = 560000.04,guaranteed_compensation = 600000.04)
# Salary(clubs_id = 10,first = 'Adama',last = 'Diomande',club = 'LAFC',position = 'F',base_salary = 849999.96,guaranteed_compensation = 934999.96)
# Salary(clubs_id = 12,first = 'Clement',last = 'Diop',club = 'Montreal Impact',position = 'GK',base_salary = 94500.0,guaranteed_compensation = 98190.0)
# Salary(clubs_id = 24,first = 'Jon Erice',last = 'Dominguez',club = 'Vancouver Whitecaps',position = 'M',base_salary = 654545.52,guaranteed_compensation = 752363.7)
# Salary(clubs_id = 23,first = 'Griffin',last = 'Dorsey',club = 'Toronto FC',position = 'M-F',base_salary = 90000.0,guaranteed_compensation = 134000.0)
# Salary(clubs_id = 9,first = 'Jonathan',last = 'dos Santos',club = 'LA Galaxy',position = 'M',base_salary = 2000000.04,guaranteed_compensation = 2000000.04)
# Salary(clubs_id = 11,first = 'Hassani',last = 'Dotson',club = 'Minnesota United',position = 'M',base_salary = 56250.0,guaranteed_compensation = 56250.0)
# Salary(clubs_id = 22,first = 'Cameron',last = 'Duke',club = 'Sporting Kansas City',position = 'M',base_salary = 56250.0,guaranteed_compensation = 69250.0)
# Salary(clubs_id = 15,first = 'Kyle',last = 'Duncan',club = 'New York Red Bulls',position = 'D',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 23,first = 'Julian',last = 'Dunn',club = 'Toronto FC',position = 'D',base_salary = 57225.0,guaranteed_compensation = 57225.0)
# Salary(clubs_id = 5,first = 'Chris',last = 'Durkin',club = 'DC United',position = 'D-M',base_salary = 95000.04,guaranteed_compensation = 104375.04)
# Salary(clubs_id = 16,first = 'Dom',last = 'Dwyer',club = 'Orlando City SC',position = 'F',base_salary = 1320000.0,guaranteed_compensation = 1503333.33)
# Salary(clubs_id = 18,first = 'Jeremy',last = 'Ebobisse',club = 'Portland Timbers',position = 'F',base_salary = 174999.96,guaranteed_compensation = 237999.96)
# Salary(clubs_id = 2,first = 'Raheem',last = 'Edwards',club = 'Chicago Fire',position = 'M',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 5,first = 'Earl',last = 'Edwards',club = 'DC United',position = 'GK',base_salary = 70250.04,guaranteed_compensation = 73583.37)
# Salary(clubs_id = 10,first = 'Philip',last = 'Ejimadu',club = 'LAFC',position = 'GK',base_salary = 56250.0,guaranteed_compensation = 56250.0)
# Salary(clubs_id = 10,first = 'Mohammed',last = 'El-Mounir',club = 'LAFC',position = 'D',base_salary = 185000.04,guaranteed_compensation = 207666.71)
# Salary(clubs_id = 8,first = 'Alberth',last = 'Elis',club = 'Houston Dynamo',position = 'M-F',base_salary = 650340.0,guaranteed_compensation = 650340.0)
# Salary(clubs_id = 17,first = 'Jack',last = 'Elliott',club = 'Philadelphia Union',position = 'D',base_salary = 250000.08,guaranteed_compensation = 265000.08)
# Salary(clubs_id = 23,first = 'Tsubasa',last = 'Endoh',club = 'Toronto FC',position = 'M-F',base_salary = 70250.04,guaranteed_compensation = 75583.37)
# Salary(clubs_id = 15,first = 'Marcus',last = 'Epps',club = 'New York Red Bulls',position = 'M-F',base_salary = 70250.04,guaranteed_compensation = 74541.71)
# Salary(clubs_id = 20,first = 'Magnus',last = 'Eriksson',club = 'San Jose Earthquakes',position = 'M-F',base_salary = 450000.0,guaranteed_compensation = 450000.0)
# Salary(clubs_id = 1,first = 'Franco',last = 'Escobar',club = 'Atlanta United',position = 'D',base_salary = 300000.0,guaranteed_compensation = 300000.0)
# Salary(clubs_id = 20,first = 'Cristian',last = 'Espinoza',club = 'San Jose Earthquakes',position = 'M-F',base_salary = 500000.04,guaranteed_compensation = 550000.04)
# Salary(clubs_id = 22,first = 'Roger',last = 'Espinoza',club = 'Sporting Kansas City',position = 'M',base_salary = 800000.04,guaranteed_compensation = 800000.04)
# Salary(clubs_id = 6,first = 'Derrick',last = 'Etienne',club = 'FC Cincinnati',position = 'M-F',base_salary = 77062.56,guaranteed_compensation = 82062.56)
# Salary(clubs_id = 17,first = 'Marco',last = 'Fabian',club = 'Philadelphia Union',position = 'M-F',base_salary = 2000727.24,guaranteed_compensation = 2274087.24)
# Salary(clubs_id = 13,first = 'Diego',last = 'Fagundez',club = 'New England Revolution',position = 'M-F',base_salary = 185000.04,guaranteed_compensation = 205000.04)
# Salary(clubs_id = 12,first = 'Rod',last = 'Fanni',club = 'Montreal Impact',position = 'D',base_salary = 299250.0,guaranteed_compensation = 299250.0)
# Salary(clubs_id = 18,first = 'Marco',last = 'Farfan',club = 'Portland Timbers',position = 'D',base_salary = 80250.0,guaranteed_compensation = 80250.0)
# Salary(clubs_id = 13,first = 'Andrew',last = 'Farrell',club = 'New England Revolution',position = 'D',base_salary = 209229.96,guaranteed_compensation = 294230.0)
# Salary(clubs_id = 22,first = 'Benny',last = 'Feilhaber',club = 'Sporting Kansas City',position = 'M',base_salary = 413400.0,guaranteed_compensation = 463400.0)
# Salary(clubs_id = 20,first = 'Luis',last = 'Felipe',club = 'San Jose Earthquakes',position = 'D-M',base_salary = 70875.0,guaranteed_compensation = 71625.0)
# Salary(clubs_id = 9,first = 'Rolf',last = 'Feltscher',club = 'LA Galaxy',position = 'D',base_salary = 218000.04,guaranteed_compensation = 242650.04)
# Salary(clubs_id = 22,first = 'Gerso',last = 'Fernandes',club = 'Sporting Kansas City',position = 'M-F',base_salary = 550008.0,guaranteed_compensation = 550008.0)
# Salary(clubs_id = 15,first = 'Omir',last = 'Fernandez',club = 'New York Red Bulls',position = 'M-F',base_salary = 80000.04,guaranteed_compensation = 95000.04)
# Salary(clubs_id = 18,first = 'Brian',last = 'Fernandez',club = 'Portland Timbers',position = 'M-F',base_salary = 1200000.0,guaranteed_compensation = 1275800.0)
# Salary(clubs_id = 2,first = 'Marcelo',last = 'Ferreira',club = 'Chicago Fire',position = 'D',base_salary = 774999.96,guaranteed_compensation = 797499.96)
# Salary(clubs_id = 7,first = 'Jesus',last = 'Ferreira',club = 'FC Dallas',position = 'F',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 20,first = 'Carlos',last = 'Fierro',club = 'San Jose Earthquakes',position = 'M-F',base_salary = 660000.0,guaranteed_compensation = 718800.0)
# Salary(clubs_id = 8,first = 'Maynor',last = 'Figueroa',club = 'Houston Dynamo',position = 'D',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 11,first = 'Ethan',last = 'Finlay',club = 'Minnesota United',position = 'M-F',base_salary = 400008.0,guaranteed_compensation = 400008.0)
# Salary(clubs_id = 13,first = 'Nicolas',last = 'Firmino',club = 'New England Revolution',position = 'M',base_salary = 70250.04,guaranteed_compensation = 73916.71)
# Salary(clubs_id = 5,first = 'Oniel',last = 'Fisher',club = 'DC United',position = 'D',base_salary = 70250.04,guaranteed_compensation = 74916.71)
# Salary(clubs_id = 18,first = 'Andres',last = 'Flores',club = 'Portland Timbers',position = 'M-F',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 17,first = 'Anthony',last = 'Fontana',club = 'Philadelphia Union',position = 'M-F',base_salary = 70260.0,guaranteed_compensation = 78677.6)
# Salary(clubs_id = 22,first = 'Andreu',last = 'Fontas',club = 'Sporting Kansas City',position = 'D',base_salary = 1050000.0,guaranteed_compensation = 1050000.0)
# Salary(clubs_id = 3,first = 'Kortne',last = 'Ford',club = 'Colorado Rapids',position = 'D',base_salary = 92496.0,guaranteed_compensation = 92496.0)
# Salary(clubs_id = 4,first = 'Waylon',last = 'Francis',club = 'Columbus Crew',position = 'D',base_salary = 160000.08,guaranteed_compensation = 199166.75)
# Salary(clubs_id = 2,first = 'Przemyslaw',last = 'Frankowski',club = 'Chicago Fire',position = 'M-F',base_salary = 450000.0,guaranteed_compensation = 661687.5)
# Salary(clubs_id = 23,first = 'Liam',last = 'Fraser',club = 'Toronto FC',position = 'D-M',base_salary = 70875.0,guaranteed_compensation = 75875.0)
# Salary(clubs_id = 22,first = 'Tyler',last = 'Freeman',club = 'Sporting Kansas City',position = 'F',base_salary = 70249.92,guaranteed_compensation = 82749.92)
# Salary(clubs_id = 17,first = 'Matt',last = 'Freese',club = 'Philadelphia Union',position = 'GK',base_salary = 70000.08,guaranteed_compensation = 77650.08)
# Salary(clubs_id = 21,first = 'Stefan',last = 'Frei',club = 'Seattle Sounders FC',position = 'GK',base_salary = 325000.08,guaranteed_compensation = 337500.08)
# Salary(clubs_id = 8,first = 'Alejandro',last = 'Fuenmayor',club = 'Houston Dynamo',position = 'D',base_salary = 145008.0,guaranteed_compensation = 172508.0)
# Salary(clubs_id = 20,first = 'Gilbert',last = 'Fuentes',club = 'San Jose Earthquakes',position = 'M',base_salary = 80000.04,guaranteed_compensation = 92000.04)
# Salary(clubs_id = 17,first = 'Raymon',last = 'Gaddis',club = 'Philadelphia Union',position = 'D',base_salary = 190000.08,guaranteed_compensation = 190000.08)
# Salary(clubs_id = 2,first = 'Nicolas',last = 'Gaitan',club = 'Chicago Fire',position = 'M-F',base_salary = 1400004.0,guaranteed_compensation = 2197504.0)
# Salary(clubs_id = 1,first = 'Jon',last = 'Gallagher',club = 'Atlanta United',position = 'M-F',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 23,first = 'Erickson',last = 'Gallardo',club = 'Toronto FC',position = 'M',base_salary = 275004.0,guaranteed_compensation = 306916.6)
# Salary(clubs_id = 8,first = 'Oscar Boniek',last = 'Garcia',club = 'Houston Dynamo',position = 'M',base_salary = 168000.0,guaranteed_compensation = 183000.0)
# Salary(clubs_id = 8,first = 'Kevin',last = 'Garcia',club = 'Houston Dynamo',position = 'D',base_salary = 72360.84,guaranteed_compensation = 72360.84)
# Salary(clubs_id = 6,first = 'Greg',last = 'Garza',club = 'FC Cincinnati',position = 'D',base_salary = 270000.0,guaranteed_compensation = 270000.0)
# Salary(clubs_id = 11,first = 'Chase',last = 'Gasper',club = 'Minnesota United',position = 'D',base_salary = 56250.0,guaranteed_compensation = 56250.0)
# Salary(clubs_id = 6,first = 'Logan',last = 'Gdula',club = 'FC Cincinnati',position = 'D',base_salary = 56250.0,guaranteed_compensation = 59575.0)
# Salary(clubs_id = 13,first = 'Carles',last = 'Gil',club = 'New England Revolution',position = 'M-F',base_salary = 2100000.0,guaranteed_compensation = 2337500.0)
# Salary(clubs_id = 24,first = 'Victor "PC"',last = 'Giro',club = 'Vancouver Whitecaps',position = 'D-M',base_salary = 105000.0,guaranteed_compensation = 110312.5)
# Salary(clubs_id = 19,first = 'Justen',last = 'Glad',club = 'Real Salt Lake',position = 'D',base_salary = 345000.0,guaranteed_compensation = 366700.0)
# Salary(clubs_id = 20,first = 'Anibal',last = 'Godoy',club = 'San Jose Earthquakes',position = 'D-M',base_salary = 450000.0,guaranteed_compensation = 498125.0)
# Salary(clubs_id = 24,first = 'Erik',last = 'Godoy',club = 'Vancouver Whitecaps',position = 'D',base_salary = 381818.16,guaranteed_compensation = 449318.16)
# Salary(clubs_id = 7,first = 'Jesse',last = 'Gonzalez',club = 'FC Dallas',position = 'GK',base_salary = 217500.0,guaranteed_compensation = 231500.0)
# Salary(clubs_id = 23,first = 'Omar',last = 'Gonzalez',club = 'Toronto FC',position = 'D',base_salary = 918000.0,guaranteed_compensation = 1193935.5)
# Salary(clubs_id = 9,first = 'Giancarlo',last = 'Gonzalez',club = 'LA Galaxy',position = 'D',base_salary = 650000.04,guaranteed_compensation = 719583.37)
# Salary(clubs_id = 1,first = 'Leandro',last = 'Gonzalez Pirez',club = 'Atlanta United',position = 'D',base_salary = 775008.0,guaranteed_compensation = 810008.0)
# Salary(clubs_id = 1,first = 'Chris',last = 'Goslin',club = 'Atlanta United',position = 'M-F',base_salary = 90000.0,guaranteed_compensation = 90000.0)
# Salary(clubs_id = 11,first = 'Jan',last = 'Gregus',club = 'Minnesota United',position = 'M',base_salary = 750000.0,guaranteed_compensation = 883500.0)
# Salary(clubs_id = 1,first = 'Julian',last = 'Gressel',club = 'Atlanta United',position = 'M',base_salary = 114249.96,guaranteed_compensation = 132999.96)
# Salary(clubs_id = 16,first = 'Adam',last = 'Grinwis',club = 'Orlando City SC',position = 'GK',base_salary = 70875.0,guaranteed_compensation = 70875.0)
# Salary(clubs_id = 10,first = 'Alejandro',last = 'Guido',club = 'LAFC',position = 'D-M',base_salary = 120000.0,guaranteed_compensation = 120000.0)
# Salary(clubs_id = 22,first = 'Felipe',last = 'Gutierrez',club = 'Sporting Kansas City',position = 'M',base_salary = 1599999.96,guaranteed_compensation = 1649999.96)
# Salary(clubs_id = 2,first = 'Jeremiah',last = 'Gutjahr',club = 'Chicago Fire',position = 'M',base_salary = 56250.0,guaranteed_compensation = 56250.0)
# Salary(clubs_id = 6,first = 'Andrew',last = 'Gutman',club = 'FC Cincinnati',position = 'D',base_salary = 99999.96,guaranteed_compensation = 99999.96)
# Salary(clubs_id = 1,first = 'Brad',last = 'Guzan',club = 'Atlanta United',position = 'GK',base_salary = 680004.0,guaranteed_compensation = 740004.0)
# Salary(clubs_id = 4,first = 'David',last = 'Guzman',club = 'Columbus Crew',position = 'D-M',base_salary = 320000.04,guaranteed_compensation = 340000.04)
# Salary(clubs_id = 6,first = 'Joe',last = 'Gyau',club = 'FC Cincinnati',position = 'M',base_salary = 148200.0,guaranteed_compensation = 168640.0)
# Salary(clubs_id = 14,first = 'Justin',last = 'Haak',club = 'New York City FC',position = 'M',base_salary = 56250.0,guaranteed_compensation = 56250.0)
# Salary(clubs_id = 6,first = 'Nick',last = 'Hagglund',club = 'FC Cincinnati',position = 'D',base_salary = 137504.4,guaranteed_compensation = 147129.4)
# Salary(clubs_id = 6,first = 'Jimmy',last = 'Hague',club = 'FC Cincinnati',position = 'GK',base_salary = 56250.0,guaranteed_compensation = 56250.0)
# Salary(clubs_id = 8,first = 'Marlon',last = 'Hairston',club = 'Houston Dynamo',position = 'M-F',base_salary = 155004.0,guaranteed_compensation = 155004.0)
# Salary(clubs_id = 20,first = 'Siad',last = 'Haji',club = 'San Jose Earthquakes',position = 'M',base_salary = 75000.0,guaranteed_compensation = 104000.0)
# Salary(clubs_id = 5,first = 'Bill',last = 'Hamid',club = 'DC United',position = 'GK',base_salary = 461820.0,guaranteed_compensation = 487495.0)
# Salary(clubs_id = 4,first = 'Jordan',last = 'Hamilton',club = 'Columbus Crew',position = 'F',base_salary = 124992.0,guaranteed_compensation = 137658.67)
# Salary(clubs_id = 8,first = 'Niko',last = 'Hansen',club = 'Houston Dynamo',position = 'M-F',base_salary = 71662.56,guaranteed_compensation = 79162.56)
# Salary(clubs_id = 10,first = 'Jordan',last = 'Harvey',club = 'LAFC',position = 'D',base_salary = 165000.0,guaranteed_compensation = 165000.0)
# Salary(clubs_id = 24,first = 'Thomas',last = 'Hasal',club = 'Vancouver Whitecaps',position = 'GK',base_salary = 56250.0,guaranteed_compensation = 66250.0)
# Salary(clubs_id = 22,first = 'Nicolas',last = 'Hasler',club = 'Sporting Kansas City',position = 'M',base_salary = 168000.0,guaranteed_compensation = 183666.67)
# Salary(clubs_id = 7,first = 'Jacori',last = 'Hayes',club = 'FC Dallas',position = 'M',base_salary = 71662.56,guaranteed_compensation = 79162.56)
# Salary(clubs_id = 7,first = 'Matt',last = 'Hedges',club = 'FC Dallas',position = 'D',base_salary = 550008.0,guaranteed_compensation = 575008.0)
# Salary(clubs_id = 24,first = 'Doneil',last = 'Henry',club = 'Vancouver Whitecaps',position = 'D',base_salary = 190008.0,guaranteed_compensation = 204241.71)
# Salary(clubs_id = 2,first = 'Fabian',last = 'Herbers',club = 'Chicago Fire',position = 'M-F',base_salary = 135000.0,guaranteed_compensation = 135000.0)
# Salary(clubs_id = 13,first = 'Zachary',last = 'Herivaux',club = 'New England Revolution',position = 'M',base_salary = 72351.6,guaranteed_compensation = 87351.6)
# Salary(clubs_id = 1,first = 'Jose Rafael',last = 'Hernandez',club = 'Atlanta United',position = 'D',base_salary = 140004.0,guaranteed_compensation = 140004.0)
# Salary(clubs_id = 7,first = 'Moises',last = 'Hernandez',club = 'FC Dallas',position = 'D',base_salary = 90000.0,guaranteed_compensation = 90000.0)
# Salary(clubs_id = 22,first = 'Felipe',last = 'Hernandez',club = 'Sporting Kansas City',position = 'M',base_salary = 56250.0,guaranteed_compensation = 56250.0)
# Salary(clubs_id = 19,first = 'Aaron',last = 'Herrera',club = 'Real Salt Lake',position = 'D',base_salary = 86000.04,guaranteed_compensation = 86000.04)
# Salary(clubs_id = 4,first = 'Federico',last = 'Higuain',club = 'Columbus Crew',position = 'M-F',base_salary = 1100000.04,guaranteed_compensation = 1100000.04)
# Salary(clubs_id = 16,first = 'Cristian',last = 'Higuita',club = 'Orlando City SC',position = 'M',base_salary = 474996.0,guaranteed_compensation = 611662.67)
# Salary(clubs_id = 9,first = 'Tomas',last = 'Hilliard-Arce',club = 'LA Galaxy',position = 'D',base_salary = 99999.96,guaranteed_compensation = 123124.96)
# Salary(clubs_id = 20,first = 'Danny',last = 'Hoesen',club = 'San Jose Earthquakes',position = 'F',base_salary = 500000.04,guaranteed_compensation = 549666.71)
# Salary(clubs_id = 7,first = 'Ryan',last = 'Hollingshead',club = 'FC Dallas',position = 'D-M',base_salary = 174999.96,guaranteed_compensation = 174999.96)
# Salary(clubs_id = 19,first = 'Erik',last = 'Holt',club = 'Real Salt Lake',position = 'D',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 19,first = 'Alex',last = 'Horwath',club = 'Real Salt Lake',position = 'GK',base_salary = 95000.04,guaranteed_compensation = 100862.54)
# Salary(clubs_id = 3,first = 'Tim',last = 'Howard',club = 'Colorado Rapids',position = 'GK',base_salary = 2000000.04,guaranteed_compensation = 2475000.04)
# Salary(clubs_id = 6,first = 'Justin',last = 'Hoyte',club = 'FC Cincinnati',position = 'D',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 3,first = 'Matt',last = 'Hundley',club = 'Colorado Rapids',position = 'M-F',base_salary = 65000.04,guaranteed_compensation = 99000.04)
# Salary(clubs_id = 22,first = 'Erik',last = 'Hurtado',club = 'Sporting Kansas City',position = 'F',base_salary = 174999.96,guaranteed_compensation = 181249.96)
# Salary(clubs_id = 1,first = 'Emerson',last = 'Hyndman',club = 'Atlanta United',position = 'M',base_salary = 360000.0,guaranteed_compensation = 360000.0)
# Salary(clubs_id = 11,first = 'Romario',last = 'Ibarra',club = 'Minnesota United',position = 'M-F',base_salary = 500000.04,guaranteed_compensation = 546250.04)
# Salary(clubs_id = 11,first = 'Miguel',last = 'Ibarra',club = 'Minnesota United',position = 'M',base_salary = 309996.0,guaranteed_compensation = 342318.0)
# Salary(clubs_id = 14,first = 'Sebastien',last = 'Ibeagha',club = 'New York City FC',position = 'D',base_salary = 74250.0,guaranteed_compensation = 74250.0)
# Salary(clubs_id = 9,first = 'Zlatan',last = 'Ibrahimovic',club = 'LA Galaxy',position = 'F',base_salary = 7200000.0,guaranteed_compensation = 7200000.0)
# Salary(clubs_id = 17,first = 'nan',last = 'Ilsinho',club = 'Philadelphia Union',position = 'M',base_salary = 330000.0,guaranteed_compensation = 357000.0)
# Salary(clubs_id = 24,first = 'Hwang',last = 'In-Beom',club = 'Vancouver Whitecaps',position = 'M',base_salary = 600000.0,guaranteed_compensation = 655000.0)
# Salary(clubs_id = 3,first = 'Clint',last = 'Irwin',club = 'Colorado Rapids',position = 'GK',base_salary = 126000.0,guaranteed_compensation = 138707.24)
# Salary(clubs_id = 18,first = 'Aljaz',last = 'Ivacic',club = 'Portland Timbers',position = 'GK',base_salary = 150000.0,guaranteed_compensation = 160000.0)
# Salary(clubs_id = 3,first = 'Niki',last = 'Jackson',club = 'Colorado Rapids',position = 'F',base_salary = 57225.0,guaranteed_compensation = 57225.0)
# Salary(clubs_id = 12,first = 'Anthony',last = 'Jackson-Hamel',club = 'Montreal Impact',position = 'F',base_salary = 160000.08,guaranteed_compensation = 175000.08)
# Salary(clubs_id = 18,first = 'Modou',last = 'Jadama',club = 'Portland Timbers',position = 'D',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 10,first = 'Dejan',last = 'Jakovic',club = 'LAFC',position = 'D',base_salary = 150000.0,guaranteed_compensation = 153750.0)
# Salary(clubs_id = 9,first = 'Bradford',last = 'Jamieson',club = 'LA Galaxy',position = 'F',base_salary = 76403.28,guaranteed_compensation = 76403.28)
# Salary(clubs_id = 16,first = 'Robin',last = 'Jansson',club = 'Orlando City SC',position = 'D',base_salary = 261000.0,guaranteed_compensation = 289800.0)
# Salary(clubs_id = 5,first = 'Leonardo',last = 'Jara',club = 'DC United',position = 'D',base_salary = 500000.04,guaranteed_compensation = 560000.04)
# Salary(clubs_id = 4,first = 'Hector',last = 'Jimenez',club = 'Columbus Crew',position = 'D-M',base_salary = 200000.04,guaranteed_compensation = 200000.04)
# ...
# Salary(clubs_id = 12,first = 'Amar',last = 'Sejdic',club = 'Montreal Impact',position = 'M',base_salary = 56250.0,guaranteed_compensation = 56250.0)
# Salary(clubs_id = 3,first = 'Dillon',last = 'Serna',club = 'Colorado Rapids',position = 'M-F',base_salary = 120000.0,guaranteed_compensation = 120000.0)
# Salary(clubs_id = 7,first = 'Brandon',last = 'Servania',club = 'FC Dallas',position = 'M',base_salary = 160000.08,guaranteed_compensation = 211000.08)
# Salary(clubs_id = 23,first = 'Jacob',last = 'Shaffelburg',club = 'Toronto FC',position = 'M-F',base_salary = 56250.0,guaranteed_compensation = 62750.0)
# Salary(clubs_id = 1,first = 'Brek',last = 'Shea',club = 'Atlanta United',position = 'D-M',base_salary = 225000.0,guaranteed_compensation = 225000.0)
# Salary(clubs_id = 3,first = 'Andre',last = 'Shinyashiki',club = 'Colorado Rapids',position = 'F',base_salary = 84999.96,guaranteed_compensation = 94999.96)
# Salary(clubs_id = 21,first = 'Harry',last = 'Shipp',club = 'Seattle Sounders FC',position = 'M-F',base_salary = 234999.96,guaranteed_compensation = 234999.96)
# Salary(clubs_id = 12,first = 'Shamit',last = 'Shome',club = 'Montreal Impact',position = 'M',base_salary = 100000.08,guaranteed_compensation = 120000.08)
# Salary(clubs_id = 11,first = 'Bobby',last = 'Shuttleworth',club = 'Minnesota United',position = 'GK',base_salary = 174999.96,guaranteed_compensation = 191874.96)
# Salary(clubs_id = 10,first = 'Danilo',last = 'Silva',club = 'LAFC',position = 'D',base_salary = 200000.04,guaranteed_compensation = 200000.04)
# Salary(clubs_id = 19,first = 'Marcelo',last = 'Silva',club = 'Real Salt Lake',position = 'D',base_salary = 725004.0,guaranteed_compensation = 776629.0)
# Salary(clubs_id = 21,first = 'Luis',last = 'Silva',club = 'Seattle Sounders FC',position = 'F',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 15,first = 'Josh',last = 'Sims',club = 'New York Red Bulls',position = 'M',base_salary = 695967.96,guaranteed_compensation = 710467.96)
# Salary(clubs_id = 22,first = 'Seth',last = 'Sinovic',club = 'Sporting Kansas City',position = 'D',base_salary = 135000.0,guaranteed_compensation = 143000.0)
# Salary(clubs_id = 10,first = 'Pablo',last = 'Sisniega',club = 'LAFC',position = 'GK',base_salary = 105000.0,guaranteed_compensation = 105000.0)
# Salary(clubs_id = 3,first = 'Axel',last = 'Sjoberg',club = 'Colorado Rapids',position = 'D',base_salary = 174996.0,guaranteed_compensation = 179996.0)
# Salary(clubs_id = 9,first = 'Jorgen',last = 'Skjelvik',club = 'LA Galaxy',position = 'D',base_salary = 999999.96,guaranteed_compensation = 1066666.63)
# Salary(clubs_id = 2,first = 'Gabriel',last = 'Slonina',club = 'Chicago Fire',position = 'GK',base_salary = 60000.0,guaranteed_compensation = 74800.0)
# Salary(clubs_id = 3,first = 'Tommy',last = 'Smith',club = 'Colorado Rapids',position = 'D',base_salary = 600000.0,guaranteed_compensation = 640000.0)
# Salary(clubs_id = 16,first = 'Kyle',last = 'Smith',club = 'Orlando City SC',position = 'D',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 21,first = 'Brad',last = 'Smith',club = 'Seattle Sounders FC',position = 'D',base_salary = 529092.0,guaranteed_compensation = 549092.0)
# Salary(clubs_id = 22,first = 'Graham',last = 'Smith',club = 'Sporting Kansas City',position = 'D-M',base_salary = 57225.0,guaranteed_compensation = 57225.0)
# Salary(clubs_id = 4,first = 'Eduardo',last = 'Sosa',club = 'Columbus Crew',position = 'M-F',base_salary = 99999.96,guaranteed_compensation = 120199.96)
# Salary(clubs_id = 11,first = 'Dayne',last = 'St. Clair',club = 'Minnesota United',position = 'GK',base_salary = 70250.04,guaranteed_compensation = 74753.17)
# Salary(clubs_id = 16,first = 'Mason',last = 'Stajduhar',club = 'Orlando City SC',position = 'GK',base_salary = 70875.0,guaranteed_compensation = 70875.0)
# Salary(clubs_id = 6,first = 'Caleb',last = 'Stanko',club = 'FC Cincinnati',position = 'D-M',base_salary = 337500.0,guaranteed_compensation = 390833.33)
# Salary(clubs_id = 9,first = 'Daniel',last = 'Steres',club = 'LA Galaxy',position = 'D',base_salary = 150000.0,guaranteed_compensation = 157333.4)
# Salary(clubs_id = 8,first = 'Aljaz "Kiki"',last = 'Struna',club = 'Houston Dynamo',position = 'D',base_salary = 1100000.04,guaranteed_compensation = 1210000.04)
# Salary(clubs_id = 14,first = 'Brad',last = 'Stuver',club = 'New York City FC',position = 'GK',base_salary = 99999.96,guaranteed_compensation = 99999.96)
# Salary(clubs_id = 24,first = 'Scott',last = 'Sutter',club = 'Vancouver Whitecaps',position = 'D',base_salary = 155000.04,guaranteed_compensation = 170177.04)
# Salary(clubs_id = 21,first = 'Gustav',last = 'Svensson',club = 'Seattle Sounders FC',position = 'D-M',base_salary = 570000.0,guaranteed_compensation = 600000.0)
# Salary(clubs_id = 14,first = 'Ben',last = 'Sweat',club = 'New York City FC',position = 'D',base_salary = 200000.04,guaranteed_compensation = 200000.04)
# Salary(clubs_id = 12,first = 'Ballou',last = 'Tabla',club = 'Montreal Impact',position = 'M-F',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 12,first = 'Saphir',last = 'Taider',club = 'Montreal Impact',position = 'M',base_salary = 1400000.04,guaranteed_compensation = 1400000.04)
# Salary(clubs_id = 14,first = 'Ismael',last = 'Tajouri-Shradi',club = 'New York City FC',position = 'M-F',base_salary = 350000.04,guaranteed_compensation = 380500.04)
# Salary(clubs_id = 20,first = 'Andrew',last = 'Tarbell',club = 'San Jose Earthquakes',position = 'GK',base_salary = 200000.04,guaranteed_compensation = 235000.04)
# Salary(clubs_id = 15,first = 'Amro',last = 'Tarek',club = 'New York Red Bulls',position = 'D',base_salary = 150000.0,guaranteed_compensation = 156250.0)
# Salary(clubs_id = 24,first = 'Russell',last = 'Teibert',club = 'Vancouver Whitecaps',position = 'D-M',base_salary = 170000.04,guaranteed_compensation = 190000.04)
# Salary(clubs_id = 16,first = 'Ruan',last = 'Teixeira',club = 'Orlando City SC',position = 'D',base_salary = 159999.96,guaranteed_compensation = 159999.96)
# Salary(clubs_id = 23,first = 'Ryan',last = 'Telfer',club = 'Toronto FC',position = 'M-F',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 20,first = 'Tommy',last = 'Thompson',club = 'San Jose Earthquakes',position = 'D',base_salary = 174999.96,guaranteed_compensation = 174999.96)
# Salary(clubs_id = 14,first = 'Anton',last = 'Tinnerholm',club = 'New York City FC',position = 'D',base_salary = 496800.0,guaranteed_compensation = 546800.0)
# Salary(clubs_id = 19,first = 'Donny',last = 'Toia',club = 'Real Salt Lake',position = 'D',base_salary = 131254.2,guaranteed_compensation = 131254.2)
# Salary(clubs_id = 21,first = 'Nouhou',last = 'Tolo',club = 'Seattle Sounders FC',position = 'D',base_salary = 84000.0,guaranteed_compensation = 84000.0)
# Salary(clubs_id = 14,first = 'Juan Pablo',last = 'Torres',club = 'New York City FC',position = 'M',base_salary = 70250.04,guaranteed_compensation = 84750.04)
# Salary(clubs_id = 21,first = 'Roman',last = 'Torres',club = 'Seattle Sounders FC',position = 'D',base_salary = 670000.08,guaranteed_compensation = 740000.08)
# Salary(clubs_id = 11,first = 'Mason',last = 'Toye',club = 'Minnesota United',position = 'F',base_salary = 135000.0,guaranteed_compensation = 188000.0)
# Salary(clubs_id = 9,first = 'Diedie',last = 'Traore',club = 'LA Galaxy',position = 'D',base_salary = 56250.0,guaranteed_compensation = 56250.0)
# Salary(clubs_id = 4,first = 'Wil',last = 'Trapp',club = 'Columbus Crew',position = 'M',base_salary = 549996.0,guaranteed_compensation = 593746.0)
# Salary(clubs_id = 17,first = 'Auston',last = 'Trusty',club = 'Philadelphia Union',position = 'D',base_salary = 95000.04,guaranteed_compensation = 124100.04)
# Salary(clubs_id = 18,first = 'Bill',last = 'Tuiloma',club = 'Portland Timbers',position = 'D-M',base_salary = 100008.0,guaranteed_compensation = 107508.0)
# Salary(clubs_id = 13,first = 'Matt',last = 'Turner',club = 'New England Revolution',position = 'GK',base_salary = 75937.56,guaranteed_compensation = 75937.56)
# Salary(clubs_id = 7,first = 'Ema',last = 'Twumasi',club = 'FC Dallas',position = 'M-F',base_salary = 150000.0,guaranteed_compensation = 196900.0)
# Salary(clubs_id = 6,first = 'Przemyslaw',last = 'Tyton',club = 'FC Cincinnati',position = 'GK',base_salary = 231750.0,guaranteed_compensation = 328438.0)
# Salary(clubs_id = 6,first = 'Victor',last = 'Ulloa',club = 'FC Cincinnati',position = 'D-M',base_salary = 210000.0,guaranteed_compensation = 212500.0)
# Salary(clubs_id = 12,first = 'Maximiliano',last = 'Urruti',club = 'Montreal Impact',position = 'F',base_salary = 900000.0,guaranteed_compensation = 1071000.0)
# Salary(clubs_id = 18,first = 'Zarek',last = 'Valentin',club = 'Portland Timbers',position = 'D',base_salary = 159999.96,guaranteed_compensation = 159999.96)
# Salary(clubs_id = 4,first = 'Milton',last = 'Valenzuela',club = 'Columbus Crew',position = 'D',base_salary = 290000.04,guaranteed_compensation = 321300.04)
# Salary(clubs_id = 18,first = 'Diego',last = 'Valeri',club = 'Portland Timbers',position = 'M-F',base_salary = 2319999.96,guaranteed_compensation = 2419999.96)
# Salary(clubs_id = 15,first = 'Florian',last = 'Valot',club = 'New York Red Bulls',position = 'M-F',base_salary = 70872.0,guaranteed_compensation = 74508.45)
# Salary(clubs_id = 6,first = 'Maikel',last = 'Van Der Werff',club = 'FC Cincinnati',position = 'D',base_salary = 549999.96,guaranteed_compensation = 635166.63)
# Salary(clubs_id = 12,first = 'Jeisson',last = 'Vargas',club = 'Montreal Impact',position = 'M-F',base_salary = 225000.0,guaranteed_compensation = 225000.0)
# Salary(clubs_id = 10,first = 'Peter',last = 'Vassell',club = 'LAFC',position = 'M-F',base_salary = 70250.04,guaranteed_compensation = 72750.04)
# Salary(clubs_id = 1,first = 'Brandon',last = 'Vazquez',club = 'Atlanta United',position = 'F',base_salary = 150000.0,guaranteed_compensation = 166000.0)
# Salary(clubs_id = 19,first = 'Julian',last = 'Vazquez',club = 'Real Salt Lake',position = 'F',base_salary = 56250.0,guaranteed_compensation = 66250.0)
# Salary(clubs_id = 20,first = 'Daniel',last = 'Vega',club = 'San Jose Earthquakes',position = 'GK',base_salary = 200000.04,guaranteed_compensation = 210000.04)
# Salary(clubs_id = 10,first = 'Carlos',last = 'Vela',club = 'LAFC',position = 'M-F',base_salary = 4500000.0,guaranteed_compensation = 6300000.0)
# Salary(clubs_id = 8,first = 'Matias Gabriel',last = 'Vera',club = 'Houston Dynamo',position = 'D-M',base_salary = 225000.0,guaranteed_compensation = 231250.0)
# Salary(clubs_id = 18,first = 'Jorge',last = 'Villafaña',club = 'Portland Timbers',position = 'D',base_salary = 600000.0,guaranteed_compensation = 617500.0)
# Salary(clubs_id = 1,first = 'Hector',last = 'Villalba',club = 'Atlanta United',position = 'M-F',base_salary = 722499.96,guaranteed_compensation = 830249.96)
# Salary(clubs_id = 3,first = 'Sam',last = 'Vines',club = 'Colorado Rapids',position = 'D',base_salary = 80000.04,guaranteed_compensation = 81250.04)
# Salary(clubs_id = 9,first = 'Justin',last = 'Vom Steeg',club = 'LA Galaxy',position = 'GK',base_salary = 57225.0,guaranteed_compensation = 57225.0)
# Salary(clubs_id = 17,first = 'Kai',last = 'Wagner',club = 'Philadelphia Union',position = 'D',base_salary = 318000.0,guaranteed_compensation = 360150.0)
# Salary(clubs_id = 22,first = 'Rodney',last = 'Wallace',club = 'Sporting Kansas City',position = 'M',base_salary = 360000.0,guaranteed_compensation = 360000.0)
# Salary(clubs_id = 6,first = 'Kendall',last = 'Waston',club = 'FC Cincinnati',position = 'D',base_salary = 750000.0,guaranteed_compensation = 776666.67)
# Salary(clubs_id = 23,first = 'Quentin',last = 'Westberg',club = 'Toronto FC',position = 'GK',base_salary = 100000.08,guaranteed_compensation = 115254.08)
# Salary(clubs_id = 15,first = 'Brian',last = 'White',club = 'New York Red Bulls',position = 'F',base_salary = 57225.0,guaranteed_compensation = 57225.0)
# Salary(clubs_id = 5,first = 'Gordon',last = 'Wild',club = 'DC United',position = 'F',base_salary = 99999.96,guaranteed_compensation = 129999.96)
# Salary(clubs_id = 4,first = 'Romario',last = 'Williams',club = 'Columbus Crew',position = 'F',base_salary = 78650.04,guaranteed_compensation = 78650.04)
# Salary(clubs_id = 4,first = 'Josh',last = 'Williams',club = 'Columbus Crew',position = 'D',base_salary = 215000.04,guaranteed_compensation = 215000.04)
# Salary(clubs_id = 4,first = 'JJ',last = 'Williams',club = 'Columbus Crew',position = 'F',base_salary = 95000.04,guaranteed_compensation = 149750.04)
# Salary(clubs_id = 18,first = 'Eryk',last = 'Williamson',club = 'Portland Timbers',position = 'M',base_salary = 120000.0,guaranteed_compensation = 136500.0)
# Salary(clubs_id = 8,first = 'Joe',last = 'Willis',club = 'Houston Dynamo',position = 'GK',base_salary = 165000.0,guaranteed_compensation = 172833.33)
# Salary(clubs_id = 3,first = 'Danny',last = 'Wilson',club = 'Colorado Rapids',position = 'D',base_salary = 500000.04,guaranteed_compensation = 540000.04)
# Salary(clubs_id = 20,first = 'Chris',last = 'Wondolowski',club = 'San Jose Earthquakes',position = 'F',base_salary = 800000.04,guaranteed_compensation = 800000.04)
# Salary(clubs_id = 17,first = 'Andrew',last = 'Wooten',club = 'Philadelphia Union',position = 'F',base_salary = 510000.0,guaranteed_compensation = 595833.33)
# Salary(clubs_id = 13,first = 'Brian',last = 'Wright',club = 'New England Revolution',position = 'F',base_salary = 70875.0,guaranteed_compensation = 70875.0)
# Salary(clubs_id = 15,first = 'Bradley',last = 'Wright-Phillips',club = 'New York Red Bulls',position = 'F',base_salary = 1200000.0,guaranteed_compensation = 1380000.0)
# Salary(clubs_id = 3,first = 'Deklan',last = 'Wynne',club = 'Colorado Rapids',position = 'D',base_salary = 74250.0,guaranteed_compensation = 74250.0)
# Salary(clubs_id = 12,first = 'Karifa',last = 'Yao',club = 'Montreal Impact',position = 'D',base_salary = 56250.0,guaranteed_compensation = 60466.39)
# Salary(clubs_id = 5,first = 'Griffin',last = 'Yow',club = 'DC United',position = 'F',base_salary = 70250.04,guaranteed_compensation = 76368.37)
# Salary(clubs_id = 20,first = 'Jackson',last = 'Yueill',club = 'San Jose Earthquakes',position = 'M',base_salary = 145000.08,guaranteed_compensation = 190000.08)
# Salary(clubs_id = 13,first = 'Wilfred',last = 'Zahibo',club = 'New England Revolution',position = 'M',base_salary = 513000.0,guaranteed_compensation = 583000.0)
# Salary(clubs_id = 18,first = 'Renzo',last = 'Zambrano',club = 'Portland Timbers',position = 'M',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 4,first = 'Gyasi',last = 'Zardes',club = 'Columbus Crew',position = 'F',base_salary = 1421666.64,guaranteed_compensation = 1471666.64)
# Salary(clubs_id = 23,first = 'Eriq',last = 'Zavaleta',club = 'Toronto FC',position = 'D',base_salary = 275004.0,guaranteed_compensation = 296962.33)
# Salary(clubs_id = 22,first = 'Gedion',last = 'Zelalem',club = 'Sporting Kansas City',position = 'M',base_salary = 56250.0,guaranteed_compensation = 77916.67)
# Salary(clubs_id = 10,first = 'Rodolfo',last = 'Zelaya',club = 'LAFC',position = 'F',base_salary = 162500.04,guaranteed_compensation = 185833.37)
# Salary(clubs_id = 22,first = 'Adrian',last = 'Zendejas',club = 'Sporting Kansas City',position = 'GK',base_salary = 70250.04,guaranteed_compensation = 70250.04)
# Salary(clubs_id = 7,first = 'Reto',last = 'Ziegler',club = 'FC Dallas',position = 'D',base_salary = 820000.08,guaranteed_compensation = 870000.08)
# Salary(clubs_id = 10,first = 'Walker',last = 'Zimmerman',club = 'LAFC',position = 'D',base_salary = 600000.0,guaranteed_compensation = 600000.0)
# Salary(clubs_id = 7,first = 'Kyle',last = 'Zobeck',club = 'FC Dallas',position = 'GK',base_salary = 70875.0,guaranteed_compensation = 70875.0)
# Salary(clubs_id = 9,first = 'Ethan',last = 'Zubak',club = 'LA Galaxy',position = 'F',base_salary = 75000.0,guaranteed_compensation = 78125.0)
# Salary(clubs_id = 22,first = 'Graham',last = 'Zusi',club = 'Sporting Kansas City',position = 'D-M',base_salary = 625000.08,guaranteed_compensation = 688333.41)

# %%
# club_id	first	last	nation	position	club	age	born	mp	starts	minutes	goals	assists	pk	pkatt	yellow_card	red_card
for row in players_df.iterrows(): 
    players = Players(clubs_id= row[1]['club_id'],first=row[1]['first'],last=row[1]['last'],nation=row[1]['nation'],position=row[1]
                      ['position'],club=row[1]['club'],age=row[1]['age'],born=row[1]['born'],mp=row[1]['mp'],starts=row[1]['starts'],
                      goals=row[1]['goals'],assists=row[1]['assists'],pk=row[1]['pk'],pkatt=row[1]['pkatt'],
                      yellow_card=row[1]['yellow_card'],red_card=row[1]['red_card'])
    print(players)
    session.add(players)
# Out:
# Player(clubs_id = 17,first = 'Brenden',last = 'Aaronson',nation = 'us USA',position = 'MF,FW',club = 'Philadelphia Union',age = 18.0,born = 2000.0,mp = 28.0,starts = 25.0,goals = 3.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 3.0,red_card = 0.0)
# Player(clubs_id = 21,first = 'Saad',last = 'Abdul-Salaam',nation = 'us USA',position = 'DF',club = 'Seattle Sounders FC',age = 27.0,born = 1991.0,mp = 18.0,starts = 11.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 3,first = 'Lalas',last = 'Abubakar',nation = 'gh GHA',position = 'DF',club = 'Colorado Rapids',age = 24.0,born = 1994.0,mp = 22.0,starts = 22.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 7.0,red_card = 0.0)
# Player(clubs_id = 4,first = 'Lalas',last = 'Abubakar',nation = 'gh GHA',position = 'DF',club = 'Columbus Crew',age = 24.0,born = 1994.0,mp = 1.0,starts = 1.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 17,first = 'David',last = 'Accam',nation = 'gh GHA',position = 'FW',club = 'Philadelphia Union',age = 28.0,born = 1990.0,mp = 8.0,starts = 4.0,goals = 4.0,assists = 2.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 4,first = 'David',last = 'Accam',nation = 'gh GHA',position = 'FW,MF',club = 'Columbus Crew',age = 28.0,born = 1990.0,mp = 15.0,starts = 8.0,goals = 2.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 7,first = 'Bryan',last = 'Acosta',nation = 'hn HON',position = 'MF',club = 'FC Dallas',age = 25.0,born = 1993.0,mp = 26.0,starts = 23.0,goals = 2.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 12.0,red_card = 0.0)
# Player(clubs_id = 16,first = 'Danilo',last = 'Acosta',nation = 'us USA',position = 'DF',club = 'Orlando City SC',age = 21.0,born = 1997.0,mp = 8.0,starts = 8.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 3,first = 'Kellyn',last = 'Acosta',nation = 'us USA',position = 'MF',club = 'Colorado Rapids',age = 23.0,born = 1995.0,mp = 31.0,starts = 30.0,goals = 2.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 10.0,red_card = 1.0)
# Player(clubs_id = 5,first = 'Luciano',last = 'Acosta',nation = 'ar ARG',position = 'MF,FW',club = 'DC United',age = 24.0,born = 1994.0,mp = 31.0,starts = 22.0,goals = 6.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 1.0)
# Player(clubs_id = 1,first = 'Mo',last = 'Adams',nation = 'eng ENG',position = 'DF,MF',club = 'Atlanta United',age = 22.0,born = 1996.0,mp = 4.0,starts = 1.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 2,first = 'Mo',last = 'Adams',nation = 'eng ENG',position = 'MF',club = 'Chicago Fire',age = 22.0,born = 1996.0,mp = 10.0,starts = 5.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 0.0)
# Player(clubs_id = 6,first = 'Fanendo',last = 'Adi',nation = 'ng NGA',position = 'FW',club = 'FC Cincinnati',age = 28.0,born = 1990.0,mp = 12.0,starts = 7.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 24,first = 'Ali',last = 'Adnan Kadhim',nation = 'iq IRQ',position = 'DF',club = 'Vancouver Whitecaps',age = 25.0,born = 1993.0,mp = 28.0,starts = 28.0,goals = 1.0,assists = 3.0,pk = '0.0',pkatt = 1.0,yellow_card = 6.0,red_card = 0.0)
# Player(clubs_id = 20,first = 'François',last = 'Affolter',nation = 'ch SUI',position = 'DF',club = 'San Jose Earthquakes',age = 27.0,born = 1991.0,mp = 1.0,starts = 1.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 4,first = 'Harrison',last = 'Afful',nation = 'gh GHA',position = 'DF',club = 'Columbus Crew',age = 32.0,born = 1986.0,mp = 22.0,starts = 22.0,goals = 0.0,assists = 2.0,pk = '0.0',pkatt = 0.0,yellow_card = 3.0,red_card = 1.0)
# Player(clubs_id = 13,first = 'Juan',last = 'Agudelo',nation = 'us USA',position = 'MF,FW',club = 'New England Revolution',age = 26.0,born = 1992.0,mp = 28.0,starts = 21.0,goals = 3.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 7.0,red_card = 0.0)
# Player(clubs_id = 16,first = 'Tesho',last = 'Akindele',nation = 'ca CAN',position = 'FW',club = 'Orlando City SC',age = 26.0,born = 1992.0,mp = 28.0,starts = 22.0,goals = 10.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 23,first = 'Ayo',last = 'Akinola',nation = 'us USA',position = 'FW,MF',club = 'Toronto FC',age = 19.0,born = 2000.0,mp = 8.0,starts = 2.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 6,first = 'Fatai',last = 'Alashe',nation = 'us USA',position = 'MF,DF',club = 'FC Cincinnati',age = 25.0,born = 1993.0,mp = 11.0,starts = 4.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 6,first = 'Nazmi',last = 'Albadawi',nation = 'ps PLE',position = 'MF',club = 'FC Cincinnati',age = 27.0,born = 1991.0,mp = 1.0,starts = 0.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 9,first = 'Romain',last = 'Alessandrini',nation = 'fr FRA',position = 'FW',club = 'LA Galaxy',age = 29.0,born = 1989.0,mp = 5.0,starts = 5.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 6,first = 'Eric',last = 'Alexander',nation = 'us USA',position = 'MF,FW',club = 'FC Cincinnati',age = 30.0,born = 1988.0,mp = 6.0,starts = 4.0,goals = 0.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 11,first = 'Osvaldo',last = 'Alonso',nation = 'cu CUB',position = 'MF',club = 'Minnesota United',age = 33.0,born = 1985.0,mp = 27.0,starts = 27.0,goals = 2.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 0.0)
# Player(clubs_id = 23,first = 'Jozy',last = 'Altidore',nation = 'us USA',position = 'FW',club = 'Toronto FC',age = 29.0,born = 1989.0,mp = 22.0,starts = 18.0,goals = 11.0,assists = 5.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 0.0)
# Player(clubs_id = 9,first = 'Efrain',last = 'Alvarez',nation = 'mx MEX',position = 'MF,FW',club = 'LA Galaxy',age = 16.0,born = 2002.0,mp = 14.0,starts = 4.0,goals = 0.0,assists = 3.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 1.0)
# Player(clubs_id = 9,first = 'Fabio',last = 'Álvarez',nation = 'ar ARG',position = 'MF,FW',club = 'LA Galaxy',age = 26.0,born = 1993.0,mp = 18.0,starts = 16.0,goals = 3.0,assists = 4.0,pk = '0.0',pkatt = 0.0,yellow_card = 5.0,red_card = 0.0)
# Player(clubs_id = 5,first = 'Quincy',last = 'Amarikwa',nation = 'us USA',position = 'FW',club = 'DC United',age = 31.0,born = 1987.0,mp = 23.0,starts = 3.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 3.0,red_card = 0.0)
# Player(clubs_id = 6,first = 'Frankie',last = 'Amaya',nation = 'us USA',position = 'MF',club = 'FC Cincinnati',age = 18.0,born = 2000.0,mp = 19.0,starts = 15.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 1,first = 'Mikey',last = 'Ambrose',nation = 'us USA',position = 'DF',club = 'Atlanta United',age = 25.0,born = 1993.0,mp = 4.0,starts = 3.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 15,first = 'Michael',last = 'Amir Murillo',nation = 'pa PAN',position = 'DF',club = 'New York Red Bulls',age = 22.0,born = 1996.0,mp = 22.0,starts = 18.0,goals = 1.0,assists = 3.0,pk = '0.0',pkatt = 0.0,yellow_card = 6.0,red_card = 1.0)
# Player(clubs_id = 3,first = 'Sebastian',last = 'Anderson',nation = 'us USA',position = 'DF,FW',club = 'Colorado Rapids',age = 16.0,born = 2002.0,mp = 6.0,starts = 5.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 1.0)
# Player(clubs_id = 13,first = 'Jalil',last = 'Anibaba',nation = 'us USA',position = 'DF',club = 'New England Revolution',age = 30.0,born = 1988.0,mp = 22.0,starts = 19.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 1.0)
# Player(clubs_id = 9,first = 'Uriel',last = 'Antuna',nation = 'mx MEX',position = 'FW,MF',club = 'LA Galaxy',age = 21.0,born = 1997.0,mp = 31.0,starts = 29.0,goals = 6.0,assists = 5.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 7,first = 'Pablo',last = 'Aránguiz',nation = 'cl CHI',position = 'MF,FW',club = 'FC Dallas',age = 21.0,born = 1997.0,mp = 11.0,starts = 7.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 9,first = 'Julian',last = 'Araujo',nation = 'us USA',position = 'DF,FW',club = 'LA Galaxy',age = 17.0,born = 2001.0,mp = 18.0,starts = 10.0,goals = 0.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 3.0,red_card = 0.0)
# Player(clubs_id = 24,first = 'Joaquín',last = 'Ardaiz',nation = 'uy URU',position = 'FW',club = 'Vancouver Whitecaps',age = 20.0,born = 1999.0,mp = 16.0,starts = 3.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 4,first = 'Luis',last = 'Argudo',nation = 'us USA',position = 'FW,MF',club = 'Columbus Crew',age = 23.0,born = 1995.0,mp = 21.0,starts = 10.0,goals = 1.0,assists = 3.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 21,first = 'Xavier',last = 'Arreaga',nation = 'ec ECU',position = 'DF',club = 'Seattle Sounders FC',age = 24.0,born = 1994.0,mp = 14.0,starts = 12.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 5.0,red_card = 2.0)
# Player(clubs_id = 19,first = 'Luis',last = 'Arriaga',nation = 'us USA',position = 'DF,MF',club = 'Real Salt Lake',age = 18.0,born = 2001.0,mp = 2.0,starts = 0.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 5,first = 'Paul',last = 'Arriola',nation = 'us USA',position = 'FW,MF',club = 'DC United',age = 23.0,born = 1995.0,mp = 29.0,starts = 28.0,goals = 6.0,assists = 2.0,pk = '0.0',pkatt = 0.0,yellow_card = 6.0,red_card = 1.0)
# Player(clubs_id = 4,first = 'Artur',last = 'None',nation = 'br BRA',position = 'MF',club = 'Columbus Crew',age = 22.0,born = 1996.0,mp = 30.0,starts = 28.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 0.0)
# Player(clubs_id = 16,first = 'Carlos',last = 'Ascues',nation = 'pe PER',position = 'MF,DF',club = 'Orlando City SC',age = 26.0,born = 1992.0,mp = 17.0,starts = 14.0,goals = 1.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 18,first = 'Dairon',last = 'Asprilla',nation = 'co COL',position = 'FW,MF',club = 'Portland Timbers',age = 26.0,born = 1992.0,mp = 13.0,starts = 7.0,goals = 2.0,assists = 0.0,pk = '1.0',pkatt = 1.0,yellow_card = 1.0,red_card = 1.0)
# Player(clubs_id = 18,first = 'Jeff',last = 'Attinella',nation = 'us USA',position = 'GK',club = 'Portland Timbers',age = 30.0,born = 1988.0,mp = 10.0,starts = 10.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 7,first = 'Francis',last = 'Atuahene',nation = 'gh GHA',position = 'FW',club = 'FC Dallas',age = 22.0,born = 1996.0,mp = 1.0,starts = 0.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 10,first = 'Eduard',last = 'Atuesta',nation = 'co COL',position = 'MF',club = 'LAFC',age = 21.0,born = 1997.0,mp = 30.0,starts = 30.0,goals = 3.0,assists = 8.0,pk = '0.0',pkatt = 0.0,yellow_card = 8.0,red_card = 0.0)
# Player(clubs_id = 23,first = 'Auro',last = 'None',nation = 'br BRA',position = 'DF',club = 'Toronto FC',age = 23.0,born = 1996.0,mp = 23.0,starts = 22.0,goals = 0.0,assists = 3.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 2,first = 'Micheal',last = 'Azira',nation = 'ug UGA',position = 'MF',club = 'Chicago Fire',age = 31.0,born = 1987.0,mp = 4.0,starts = 2.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 12,first = 'Micheal',last = 'Azira',nation = 'ug UGA',position = 'MF',club = 'Montreal Impact',age = 31.0,born = 1987.0,mp = 19.0,starts = 16.0,goals = 0.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 3.0,red_card = 0.0)
# Player(clubs_id = 7,first = 'Dominique',last = 'Badji',nation = 'sn SEN',position = 'FW',club = 'FC Dallas',age = 26.0,born = 1992.0,mp = 28.0,starts = 24.0,goals = 6.0,assists = 3.0,pk = '0.0',pkatt = 0.0,yellow_card = 6.0,red_card = 0.0)
# Player(clubs_id = 24,first = 'Theo',last = 'Bair',nation = 'ca CAN',position = 'FW,MF',club = 'Vancouver Whitecaps',age = 19.0,born = 1999.0,mp = 17.0,starts = 10.0,goals = 2.0,assists = 2.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 19,first = 'Corey',last = 'Baird',nation = 'us USA',position = 'FW,MF',club = 'Real Salt Lake',age = 23.0,born = 1996.0,mp = 31.0,starts = 23.0,goals = 5.0,assists = 3.0,pk = '0.0',pkatt = 0.0,yellow_card = 6.0,red_card = 0.0)
# Player(clubs_id = 24,first = 'Lass',last = 'Bangoura',nation = 'gn GUI',position = 'FW',club = 'Vancouver Whitecaps',age = 26.0,born = 1992.0,mp = 17.0,starts = 7.0,goals = 1.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 22,first = 'Botond',last = 'Baráth',nation = 'hu HUN',position = 'DF',club = 'Sporting Kansas City',age = 26.0,born = 1992.0,mp = 21.0,starts = 20.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 6.0,red_card = 0.0)
# Player(clubs_id = 1,first = 'Ezequiel',last = 'Barco',nation = 'ar ARG',position = 'FW,MF',club = 'Atlanta United',age = 19.0,born = 1999.0,mp = 15.0,starts = 11.0,goals = 4.0,assists = 2.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 15,first = 'Tom',last = 'Barlow',nation = 'us USA',position = 'FW',club = 'New York Red Bulls',age = 23.0,born = 1995.0,mp = 12.0,starts = 8.0,goals = 3.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 7,first = 'Michael',last = 'Barrios',nation = 'co COL',position = 'FW',club = 'FC Dallas',age = 27.0,born = 1991.0,mp = 32.0,starts = 31.0,goals = 5.0,assists = 13.0,pk = '0.0',pkatt = 0.0,yellow_card = 6.0,red_card = 0.0)
# Player(clubs_id = 3,first = 'Cole',last = 'Bassett',nation = 'us USA',position = 'MF',club = 'Colorado Rapids',age = 17.0,born = 2001.0,mp = 20.0,starts = 14.0,goals = 2.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 12,first = 'Clement',last = 'Bayiha',nation = 'ca CAN',position = 'FW,MF',club = 'Montreal Impact',age = 19.0,born = 1999.0,mp = 11.0,starts = 4.0,goals = 0.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 8,first = 'DaMarcus',last = 'Beasley',nation = 'us USA',position = 'DF',club = 'Houston Dynamo',age = 36.0,born = 1982.0,mp = 12.0,starts = 12.0,goals = 0.0,assists = 2.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 19,first = 'Kyle',last = 'Beckerman',nation = 'us USA',position = 'MF',club = 'Real Salt Lake',age = 36.0,born = 1982.0,mp = 25.0,starts = 24.0,goals = 0.0,assists = 4.0,pk = '0.0',pkatt = 0.0,yellow_card = 9.0,red_card = 0.0)
# Player(clubs_id = 17,first = 'Alejandro',last = 'Bedoya',nation = 'us USA',position = 'MF',club = 'Philadelphia Union',age = 31.0,born = 1987.0,mp = 32.0,starts = 32.0,goals = 4.0,assists = 3.0,pk = '0.0',pkatt = 0.0,yellow_card = 6.0,red_card = 0.0)
# Player(clubs_id = 14,first = 'Dan',last = 'Bedoya',nation = 'co COL',position = 'FW',club = 'New York City FC',age = 24.0,born = 1994.0,mp = 1.0,starts = 0.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 10,first = 'Steven',last = 'Beitashour',nation = 'ir IRN',position = 'DF',club = 'LAFC',age = 31.0,born = 1987.0,mp = 25.0,starts = 24.0,goals = 1.0,assists = 2.0,pk = '0.0',pkatt = 0.0,yellow_card = 3.0,red_card = 0.0)
# Player(clubs_id = 4,first = 'Joe',last = 'Bendik',nation = 'us USA',position = 'GK',club = 'Columbus Crew',age = 29.0,born = 1989.0,mp = 6.0,starts = 6.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 23,first = 'Nicolas',last = 'Benezet',nation = 'fr FRA',position = 'FW,MF',club = 'Toronto FC',age = 27.0,born = 1991.0,mp = 8.0,starts = 5.0,goals = 2.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 6,first = 'Leonardo',last = 'Bertone',nation = 'ch SUI',position = 'MF',club = 'FC Cincinnati',age = 24.0,born = 1994.0,mp = 25.0,starts = 22.0,goals = 1.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 9.0,red_card = 0.0)
# Player(clubs_id = 22,first = 'Matt',last = 'Besler',nation = 'us USA',position = 'DF',club = 'Sporting Kansas City',age = 31.0,born = 1987.0,mp = 27.0,starts = 25.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 1.0)
# Player(clubs_id = 19,first = 'Nick',last = 'Besler',nation = 'us USA',position = 'MF',club = 'Real Salt Lake',age = 25.0,born = 1993.0,mp = 17.0,starts = 7.0,goals = 1.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 0.0)
# Player(clubs_id = 15,first = 'Vincent',last = 'Bezecourt',nation = 'fr FRA',position = 'MF',club = 'New York Red Bulls',age = 25.0,born = 1993.0,mp = 8.0,starts = 7.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 9,first = 'David',last = 'Bingham',nation = 'us USA',position = 'GK',club = 'LA Galaxy',age = 29.0,born = 1989.0,mp = 33.0,starts = 33.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 5,first = 'Steve',last = 'Birnbaum',nation = 'us USA',position = 'DF',club = 'DC United',age = 28.0,born = 1991.0,mp = 34.0,starts = 34.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 5.0,red_card = 0.0)
# Player(clubs_id = 8,first = 'José',last = 'Bizama',nation = 'cl CHI',position = 'DF',club = 'Houston Dynamo',age = 24.0,born = 1994.0,mp = 5.0,starts = 4.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 10,first = 'Tristan',last = 'Blackmon',nation = 'us USA',position = 'DF',club = 'LAFC',age = 22.0,born = 1996.0,mp = 18.0,starts = 15.0,goals = 1.0,assists = 4.0,pk = '0.0',pkatt = 0.0,yellow_card = 3.0,red_card = 0.0)
# Player(clubs_id = 17,first = 'Andre',last = 'Blake',nation = 'jm JAM',position = 'GK',club = 'Philadelphia Union',age = 28.0,born = 1990.0,mp = 26.0,starts = 26.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 18,first = 'Sebastián',last = 'Blanco',nation = 'ar ARG',position = 'FW,MF',club = 'Portland Timbers',age = 30.0,born = 1988.0,mp = 30.0,starts = 28.0,goals = 6.0,assists = 10.0,pk = '0.0',pkatt = 0.0,yellow_card = 8.0,red_card = 0.0)
# Player(clubs_id = 10,first = 'Latif',last = 'Blessing',nation = 'gh GHA',position = 'MF',club = 'LAFC',age = 22.0,born = 1996.0,mp = 34.0,starts = 29.0,goals = 6.0,assists = 3.0,pk = '0.0',pkatt = 0.0,yellow_card = 7.0,red_card = 0.0)
# Player(clubs_id = 3,first = 'Johan',last = 'Blomberg',nation = 'se SWE',position = 'MF,FW',club = 'Colorado Rapids',age = 31.0,born = 1987.0,mp = 3.0,starts = 1.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 1.0)
# Player(clubs_id = 9,first = 'Emmanuel',last = 'Boateng',nation = 'gh GHA',position = 'FW,MF',club = 'LA Galaxy',age = 25.0,born = 1994.0,mp = 21.0,starts = 7.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 5,first = 'Emmanuel',last = 'Boateng',nation = 'gh GHA',position = 'FW,MF',club = 'DC United',age = 25.0,born = 1994.0,mp = 3.0,starts = 0.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 6,first = 'Corben',last = 'Bone',nation = 'us USA',position = 'MF,FW',club = 'FC Cincinnati',age = 30.0,born = 1988.0,mp = 6.0,starts = 2.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 23,first = 'Alex',last = 'Bono',nation = 'us USA',position = 'GK',club = 'Toronto FC',age = 24.0,born = 1994.0,mp = 7.0,starts = 6.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 2,first = 'Jonathan',last = 'Bornstein',nation = 'us USA',position = 'DF',club = 'Chicago Fire',age = 34.0,born = 1984.0,mp = 11.0,starts = 11.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 13,first = 'Gustavo',last = 'Bou',nation = 'ar ARG',position = 'FW,MF',club = 'New England Revolution',age = 28.0,born = 1990.0,mp = 14.0,starts = 13.0,goals = 9.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 11,first = 'Michael',last = 'Boxall',nation = 'nz NZL',position = 'DF',club = 'Minnesota United',age = 30.0,born = 1988.0,mp = 29.0,starts = 29.0,goals = 2.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 3.0,red_card = 0.0)
# Player(clubs_id = 23,first = 'Terrence',last = 'Boyd',nation = 'us USA',position = 'FW,MF',club = 'Toronto FC',age = 27.0,born = 1991.0,mp = 11.0,starts = 3.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 23,first = 'Michael',last = 'Bradley',nation = 'us USA',position = 'MF',club = 'Toronto FC',age = 31.0,born = 1987.0,mp = 27.0,starts = 26.0,goals = 3.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 0.0)
# Player(clubs_id = 12,first = 'Zachary',last = 'Brault-Guillard',nation = 'ca CAN',position = 'DF',club = 'Montreal Impact',age = 20.0,born = 1998.0,mp = 13.0,starts = 9.0,goals = 0.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 7,first = 'Bressan',last = 'None',nation = 'br BRA',position = 'DF',club = 'FC Dallas',age = 26.0,born = 1993.0,mp = 18.0,starts = 12.0,goals = 1.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 10,first = 'Shaft',last = 'Brewer',nation = 'us USA',position = 'DF',club = 'LAFC',age = 19.0,born = 1999.0,mp = 1.0,starts = 1.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 5,first = 'Frédéric',last = 'Brillant',nation = 'fr FRA',position = 'DF',club = 'DC United',age = 33.0,born = 1985.0,mp = 34.0,starts = 33.0,goals = 2.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 5.0,red_card = 0.0)
# Player(clubs_id = 2,first = 'Brandt',last = 'Bronico',nation = 'us USA',position = 'MF,DF',club = 'Chicago Fire',age = 23.0,born = 1995.0,mp = 29.0,starts = 20.0,goals = 1.0,assists = 2.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 12,first = 'Omar',last = 'Browne',nation = 'pa PAN',position = 'FW,MF',club = 'Montreal Impact',age = 24.0,born = 1994.0,mp = 10.0,starts = 5.0,goals = 2.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 21,first = 'Will',last = 'Bruin',nation = 'us USA',position = 'FW',club = 'Seattle Sounders FC',age = 29.0,born = 1989.0,mp = 9.0,starts = 4.0,goals = 2.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 13,first = 'Tajon',last = 'Buchanan',nation = 'ca CAN',position = 'MF',club = 'New England Revolution',age = 19.0,born = 1999.0,mp = 10.0,starts = 4.0,goals = 0.0,assists = 2.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 15,first = 'Rece',last = 'Buckmaster',nation = 'us USA',position = 'DF',club = 'New York Red Bulls',age = 22.0,born = 1996.0,mp = 6.0,starts = 6.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 13,first = 'Teal',last = 'Bunbury',nation = 'us USA',position = 'FW,MF',club = 'New England Revolution',age = 28.0,born = 1990.0,mp = 32.0,starts = 25.0,goals = 6.0,assists = 2.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 17,first = 'Cory',last = 'Burke',nation = 'jm JAM',position = 'FW',club = 'Philadelphia Union',age = 27.0,born = 1991.0,mp = 7.0,starts = 5.0,goals = 2.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 12,first = 'Evan',last = 'Bush',nation = 'us USA',position = 'GK',club = 'Montreal Impact',age = 32.0,born = 1986.0,mp = 32.0,starts = 32.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 3.0,red_card = 0.0)
# Player(clubs_id = 22,first = 'Gianluca',last = 'Busio',nation = 'us USA',position = 'MF',club = 'Sporting Kansas City',age = 16.0,born = 2002.0,mp = 22.0,starts = 10.0,goals = 3.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 21,first = 'Handwalla',last = 'Bwana',nation = 'ae UAE',position = 'FW',club = 'Seattle Sounders FC',age = 21.0,born = 1997.0,mp = 15.0,starts = 6.0,goals = 1.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 13,first = 'Brandon',last = 'Bye',nation = 'us USA',position = 'DF',club = 'New England Revolution',age = 23.0,born = 1995.0,mp = 30.0,starts = 30.0,goals = 2.0,assists = 2.0,pk = '0.0',pkatt = 0.0,yellow_card = 6.0,red_card = 1.0)
# Player(clubs_id = 12,first = 'Víctor',last = 'Cabrera',nation = 'ar ARG',position = 'DF',club = 'Montreal Impact',age = 25.0,born = 1993.0,mp = 16.0,starts = 13.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 13,first = 'Luís',last = 'Caicedo',nation = 'co COL',position = 'MF',club = 'New England Revolution',age = 22.0,born = 1996.0,mp = 31.0,starts = 27.0,goals = 0.0,assists = 0.0,pk = '1.0',pkatt = 1.0,yellow_card = 5.0,red_card = 0.0)
# Player(clubs_id = 13,first = 'Scott',last = 'Caldwell',nation = 'us USA',position = 'MF',club = 'New England Revolution',age = 27.0,born = 1991.0,mp = 20.0,starts = 12.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 14,first = 'Alexander',last = 'Callens',nation = 'pe PER',position = 'DF',club = 'New York City FC',age = 26.0,born = 1992.0,mp = 24.0,starts = 24.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 3.0,red_card = 0.0)
# Player(clubs_id = 20,first = 'Eric',last = 'Calvillo',nation = 'us USA',position = 'MF,DF',club = 'San Jose Earthquakes',age = 21.0,born = 1998.0,mp = 2.0,starts = 1.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 2,first = 'Francisco',last = 'Calvo',nation = 'cr CRC',position = 'DF',club = 'Chicago Fire',age = 26.0,born = 1992.0,mp = 23.0,starts = 21.0,goals = 3.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 0.0)
# Player(clubs_id = 11,first = 'Francisco',last = 'Calvo',nation = 'cr CRC',position = 'DF',club = 'Minnesota United',age = 26.0,born = 1992.0,mp = 7.0,starts = 7.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 1.0)
# Player(clubs_id = 12,first = 'Rudy',last = 'Camacho',nation = 'fr FRA',position = 'DF',club = 'Montreal Impact',age = 27.0,born = 1991.0,mp = 17.0,starts = 16.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 0.0)
# Player(clubs_id = 21,first = 'Jonathan',last = 'Campbell',nation = 'us USA',position = 'DF',club = 'Seattle Sounders FC',age = 25.0,born = 1993.0,mp = 4.0,starts = 4.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 2,first = 'Diego',last = 'Campos',nation = 'cr CRC',position = 'DF',club = 'Chicago Fire',age = 23.0,born = 1995.0,mp = 10.0,starts = 5.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 7,first = 'Reggie',last = 'Cannon',nation = 'us USA',position = 'DF',club = 'FC Dallas',age = 20.0,born = 1998.0,mp = 28.0,starts = 26.0,goals = 1.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 7.0,red_card = 0.0)
# Player(clubs_id = 5,first = 'Russell',last = 'Canouse',nation = 'us USA',position = 'MF,DF',club = 'DC United',age = 23.0,born = 1995.0,mp = 26.0,starts = 25.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 5.0,red_card = 0.0)
# Player(clubs_id = 1,first = 'Andrew',last = 'Carleton',nation = 'us USA',position = 'MF,FW',club = 'Atlanta United',age = 18.0,born = 2000.0,mp = 3.0,starts = 0.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 9,first = 'Servando',last = 'Carrasco',nation = 'us USA',position = 'MF',club = 'LA Galaxy',age = 30.0,born = 1988.0,mp = 16.0,starts = 3.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 18,first = 'Julio',last = 'Cascante',nation = 'cr CRC',position = 'DF',club = 'Portland Timbers',age = 25.0,born = 1993.0,mp = 22.0,starts = 16.0,goals = 0.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 1.0)
# Player(clubs_id = 15,first = 'Cristian',last = 'Cásseres',nation = 've VEN',position = 'MF',club = 'New York Red Bulls',age = 19.0,born = 2000.0,mp = 23.0,starts = 21.0,goals = 3.0,assists = 3.0,pk = '0.0',pkatt = 0.0,yellow_card = 5.0,red_card = 0.0)
# Player(clubs_id = 14,first = 'Valentín',last = 'Castellanos',nation = 'ar ARG',position = 'FW',club = 'New York City FC',age = 20.0,born = 1998.0,mp = 30.0,starts = 23.0,goals = 11.0,assists = 6.0,pk = '0.0',pkatt = 0.0,yellow_card = 7.0,red_card = 0.0)
# Player(clubs_id = 13,first = 'Edgar',last = 'Castillo',nation = 'us USA',position = 'DF',club = 'New England Revolution',age = 32.0,born = 1986.0,mp = 20.0,starts = 20.0,goals = 0.0,assists = 5.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 21,first = 'Emanuel',last = 'Cecchini',nation = 'ar ARG',position = 'MF',club = 'Seattle Sounders FC',age = 22.0,born = 1996.0,mp = 4.0,starts = 1.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 8,first = 'Darwin',last = 'Cerén',nation = 'sv SLV',position = 'MF',club = 'Houston Dynamo',age = 29.0,born = 1989.0,mp = 13.0,starts = 5.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 7,first = 'Edwin',last = 'Cerrillo',nation = 'us USA',position = 'MF',club = 'FC Dallas',age = 18.0,born = 2000.0,mp = 12.0,starts = 11.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 11,first = 'Thomás',last = 'Chacón',nation = 'uy URU',position = 'FW',club = 'Minnesota United',age = 18.0,born = 2000.0,mp = 2.0,starts = 1.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 14,first = 'Maxime',last = 'Chanot',nation = 'lu LUX',position = 'DF',club = 'New York City FC',age = 29.0,born = 1989.0,mp = 31.0,starts = 31.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 11.0,red_card = 0.0)
# Player(clubs_id = 23,first = 'Jay',last = 'Chapman',nation = 'ca CAN',position = 'MF,FW',club = 'Toronto FC',age = 25.0,born = 1994.0,mp = 17.0,starts = 5.0,goals = 2.0,assists = 2.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 18,first = 'Diego',last = 'Chará',nation = 'co COL',position = 'MF',club = 'Portland Timbers',age = 32.0,born = 1986.0,mp = 30.0,starts = 29.0,goals = 0.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 12.0,red_card = 1.0)
# Player(clubs_id = 24,first = 'Michaell',last = 'Chirinos',nation = 'hn HON',position = 'MF,FW',club = 'Vancouver Whitecaps',age = 23.0,born = 1995.0,mp = 7.0,starts = 4.0,goals = 1.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 12,first = 'Mathieu',last = 'Choiniere',nation = 'ca CAN',position = 'FW,MF',club = 'Montreal Impact',age = 19.0,born = 1999.0,mp = 17.0,starts = 6.0,goals = 0.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 23,first = 'Laurent',last = 'Ciman',nation = 'be BEL',position = 'DF',club = 'Toronto FC',age = 33.0,born = 1985.0,mp = 17.0,starts = 14.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 3.0,red_card = 0.0)
# Player(clubs_id = 4,first = 'Ricardo',last = 'Clark',nation = 'us USA',position = 'MF',club = 'Columbus Crew',age = 35.0,born = 1983.0,mp = 7.0,starts = 4.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 18,first = 'Steve',last = 'Clark',nation = 'us USA',position = 'GK',club = 'Portland Timbers',age = 32.0,born = 1986.0,mp = 24.0,starts = 24.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 17,first = 'Aurélien',last = 'Collin',nation = 'fr FRA',position = 'DF',club = 'Philadelphia Union',age = 32.0,born = 1986.0,mp = 6.0,starts = 6.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 16,first = 'Josué',last = 'Colmán',nation = 'py PAR',position = 'FW,MF',club = 'Orlando City SC',age = 20.0,born = 1998.0,mp = 8.0,starts = 1.0,goals = 0.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 18,first = 'Tomás',last = 'Conechny',nation = 'ar ARG',position = 'FW,MF',club = 'Portland Timbers',age = 20.0,born = 1998.0,mp = 16.0,starts = 2.0,goals = 1.0,assists = 2.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 24,first = 'Derek',last = 'Cornelius',nation = 'ca CAN',position = 'DF',club = 'Vancouver Whitecaps',age = 21.0,born = 1997.0,mp = 17.0,starts = 16.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 0.0)
# Player(clubs_id = 9,first = 'Joe',last = 'Corona',nation = 'us USA',position = 'MF',club = 'LA Galaxy',age = 28.0,born = 1990.0,mp = 31.0,starts = 26.0,goals = 1.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 6.0,red_card = 0.0)
# Player(clubs_id = 17,first = 'Carlos',last = 'Coronel',nation = 'br BRA',position = 'GK',club = 'Philadelphia Union',age = 22.0,born = 1996.0,mp = 4.0,starts = 3.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 17,first = 'Warren',last = 'Creavalle',nation = 'us USA',position = 'MF',club = 'Philadelphia Union',age = 28.0,born = 1990.0,mp = 13.0,starts = 5.0,goals = 0.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 24,first = 'Maxime',last = 'Crépeau',nation = 'ca CAN',position = 'GK',club = 'Vancouver Whitecaps',age = 24.0,born = 1994.0,mp = 26.0,starts = 26.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 4,first = 'Alex',last = 'Crognale',nation = 'us USA',position = 'DF',club = 'Columbus Crew',age = 24.0,born = 1994.0,mp = 12.0,starts = 9.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 5.0,red_card = 0.0)
# Player(clubs_id = 22,first = 'Yohan',last = 'Croizet',nation = 'fr FRA',position = 'FW,DF',club = 'Sporting Kansas City',age = 26.0,born = 1992.0,mp = 20.0,starts = 12.0,goals = 3.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 0.0)
# Player(clubs_id = 13,first = 'Cody',last = 'Cropper',nation = 'us USA',position = 'GK',club = 'New England Revolution',age = 25.0,born = 1993.0,mp = 7.0,starts = 7.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 6,first = 'Allan',last = 'Cruz',nation = 'cr CRC',position = 'MF,FW',club = 'FC Cincinnati',age = 22.0,born = 1996.0,mp = 22.0,starts = 21.0,goals = 7.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 5.0,red_card = 0.0)
# Player(clubs_id = 9,first = 'Emil',last = 'Cuello',nation = 'us USA',position = 'MF,FW',club = 'LA Galaxy',age = 21.0,born = 1997.0,mp = 9.0,starts = 2.0,goals = 0.0,assists = 2.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 20,first = 'Harold',last = 'Cummings',nation = 'pa PAN',position = 'DF',club = 'San Jose Earthquakes',age = 26.0,born = 1992.0,mp = 16.0,starts = 16.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 5.0,red_card = 0.0)
# Player(clubs_id = 6,first = 'Rashawn',last = 'Dally',nation = 'jm JAM',position = 'FW',club = 'FC Cincinnati',age = 22.0,born = 1997.0,mp = 12.0,starts = 8.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 20,first = 'Mario',last = 'Daniel Vega',nation = 'ar ARG',position = 'GK',club = 'San Jose Earthquakes',age = 34.0,born = 1984.0,mp = 34.0,starts = 34.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 11,first = 'Abu',last = 'Danladi',nation = 'gh GHA',position = 'FW,MF',club = 'Minnesota United',age = 23.0,born = 1995.0,mp = 24.0,starts = 4.0,goals = 2.0,assists = 2.0,pk = '0.0',pkatt = 0.0,yellow_card = 3.0,red_card = 0.0)
# Player(clubs_id = 8,first = 'Juan',last = 'David Cabezas',nation = 'co COL',position = 'MF',club = 'Houston Dynamo',age = 27.0,born = 1991.0,mp = 15.0,starts = 5.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 0.0)
# Player(clubs_id = 15,first = 'Sean',last = 'Davis',nation = 'us USA',position = 'MF',club = 'New York Red Bulls',age = 25.0,born = 1993.0,mp = 30.0,starts = 28.0,goals = 0.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 16,first = 'Alex',last = 'DeJohn',nation = 'us USA',position = 'DF',club = 'Orlando City SC',age = 27.0,born = 1991.0,mp = 6.0,starts = 6.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 8,first = 'A.J.',last = 'DeLaGarza',nation = 'gu GUM',position = 'DF',club = 'Houston Dynamo',age = 31.0,born = 1987.0,mp = 23.0,starts = 23.0,goals = 0.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 5.0,red_card = 0.0)
# Player(clubs_id = 13,first = 'Antonio',last = 'Delamea Mlinar',nation = 'si SVN',position = 'DF',club = 'New England Revolution',age = 27.0,born = 1991.0,mp = 17.0,starts = 16.0,goals = 2.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 7.0,red_card = 1.0)
# Player(clubs_id = 21,first = 'Jordy',last = 'Delem',nation = 'mq MTQ',position = 'MF',club = 'Seattle Sounders FC',age = 25.0,born = 1993.0,mp = 23.0,starts = 17.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 0.0)
# Player(clubs_id = 23,first = 'Nick',last = 'DeLeon',nation = 'us USA',position = 'MF,FW',club = 'Toronto FC',age = 28.0,born = 1990.0,mp = 32.0,starts = 23.0,goals = 6.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 23,first = 'Marky',last = 'Delgado',nation = 'us USA',position = 'MF',club = 'Toronto FC',age = 23.0,born = 1995.0,mp = 30.0,starts = 29.0,goals = 2.0,assists = 5.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 0.0)
# Player(clubs_id = 6,first = 'Mathieu',last = 'Deplagne',nation = 'fr FRA',position = 'DF',club = 'FC Cincinnati',age = 27.0,born = 1991.0,mp = 33.0,starts = 33.0,goals = 1.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 0.0)
# Player(clubs_id = 6,first = 'Maikel',last = 'van der Werff',nation = 'nl NED',position = 'DF',club = 'FC Cincinnati',age = 29.0,born = 1989.0,mp = 11.0,starts = 11.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 8,first = 'Tyler',last = 'Deric',nation = 'us USA',position = 'GK',club = 'Houston Dynamo',age = 30.0,born = 1988.0,mp = 7.0,starts = 7.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 21,first = 'Justin',last = 'Dhillon',nation = 'us USA',position = 'FW',club = 'Seattle Sounders FC',age = 23.0,born = 1995.0,mp = 5.0,starts = 3.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 12,first = 'Zakaria',last = 'Diallo',nation = 'fr FRA',position = 'DF',club = 'Montreal Impact',age = 32.0,born = 1986.0,mp = 24.0,starts = 23.0,goals = 3.0,assists = 2.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 1.0)
# Player(clubs_id = 4,first = 'Luis',last = 'Díaz',nation = 'cr CRC',position = 'FW,MF',club = 'Columbus Crew',age = 20.0,born = 1998.0,mp = 13.0,starts = 9.0,goals = 2.0,assists = 3.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 22,first = 'Eric',last = 'Dick',nation = 'us USA',position = 'GK',club = 'Sporting Kansas City',age = 24.0,born = 1994.0,mp = 1.0,starts = 1.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 18,first = 'Claude',last = 'Dielna',nation = 'GPE',position = 'DF',club = 'Portland Timbers',age = 31.0,born = 1987.0,mp = 15.0,starts = 12.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 3.0,red_card = 0.0)
# Player(clubs_id = 10,first = 'Adama',last = 'Diomande',nation = 'no NOR',position = 'FW',club = 'LAFC',age = 28.0,born = 1990.0,mp = 25.0,starts = 15.0,goals = 8.0,assists = 5.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 12,first = 'Clément',last = 'Diop',nation = 'sn SEN',position = 'GK',club = 'Montreal Impact',age = 25.0,born = 1993.0,mp = 2.0,starts = 2.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 23,first = 'Griffin',last = 'Dorsey',nation = 'us USA',position = 'DF',club = 'Toronto FC',age = 19.0,born = 1999.0,mp = 1.0,starts = 0.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 9,first = 'Jonathan',last = 'dos Santos',nation = 'mx MEX',position = 'MF',club = 'LA Galaxy',age = 28.0,born = 1990.0,mp = 29.0,starts = 29.0,goals = 2.0,assists = 3.0,pk = '1.0',pkatt = 1.0,yellow_card = 5.0,red_card = 0.0)
# Player(clubs_id = 11,first = 'Hassani',last = 'Dotson',nation = 'us USA',position = 'DF,MF',club = 'Minnesota United',age = 21.0,born = 1997.0,mp = 24.0,starts = 15.0,goals = 4.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 15,first = 'Kyle',last = 'Duncan',nation = 'us USA',position = 'DF',club = 'New York Red Bulls',age = 21.0,born = 1997.0,mp = 13.0,starts = 13.0,goals = 1.0,assists = 2.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 0.0)
# Player(clubs_id = 5,first = 'Chris',last = 'Durkin',nation = 'us USA',position = 'MF',club = 'DC United',age = 18.0,born = 2000.0,mp = 13.0,starts = 7.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 8,first = 'Chris',last = 'Duvall',nation = 'us USA',position = 'DF',club = 'Houston Dynamo',age = 27.0,born = 1991.0,mp = 1.0,starts = 1.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 16,first = 'Dom',last = 'Dwyer',nation = 'us USA',position = 'FW',club = 'Orlando City SC',age = 28.0,born = 1990.0,mp = 27.0,starts = 16.0,goals = 7.0,assists = 3.0,pk = '0.0',pkatt = 0.0,yellow_card = 6.0,red_card = 1.0)
# Player(clubs_id = 18,first = 'Jeremy',last = 'Ebobisse',nation = 'us USA',position = 'FW',club = 'Portland Timbers',age = 21.0,born = 1997.0,mp = 34.0,starts = 25.0,goals = 11.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 3.0,red_card = 0.0)
# Player(clubs_id = 2,first = 'Raheem',last = 'Edwards',nation = 'ca CAN',position = 'DF',club = 'Chicago Fire',age = 23.0,born = 1995.0,mp = 4.0,starts = 2.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 8,first = 'Alberth',last = 'Elis',nation = 'hn HON',position = 'FW,MF',club = 'Houston Dynamo',age = 22.0,born = 1996.0,mp = 26.0,starts = 22.0,goals = 9.0,assists = 8.0,pk = '2.0',pkatt = 2.0,yellow_card = 6.0,red_card = 1.0)
# Player(clubs_id = 17,first = 'Jack',last = 'Elliott',nation = 'eng ENG',position = 'DF',club = 'Philadelphia Union',age = 23.0,born = 1995.0,mp = 34.0,starts = 34.0,goals = 2.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 0.0)
# Player(clubs_id = 23,first = 'Tsubasa',last = 'Endoh',nation = 'jp JPN',position = 'FW,MF',club = 'Toronto FC',age = 25.0,born = 1993.0,mp = 13.0,starts = 10.0,goals = 3.0,assists = 2.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 15,first = 'Marcus',last = 'Epps',nation = 'us USA',position = 'MF,DF',club = 'New York Red Bulls',age = 24.0,born = 1995.0,mp = 3.0,starts = 1.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 24,first = 'Jon',last = 'Erice',nation = 'es ESP',position = 'MF',club = 'Vancouver Whitecaps',age = 32.0,born = 1986.0,mp = 21.0,starts = 21.0,goals = 0.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 20,first = 'Magnus',last = 'Eriksson',nation = 'se SWE',position = 'MF',club = 'San Jose Earthquakes',age = 28.0,born = 1990.0,mp = 32.0,starts = 32.0,goals = 6.0,assists = 7.0,pk = '1.0',pkatt = 1.0,yellow_card = 5.0,red_card = 0.0)
# Player(clubs_id = 1,first = 'Franco',last = 'Escobar',nation = 'ar ARG',position = 'DF',club = 'Atlanta United',age = 23.0,born = 1995.0,mp = 25.0,starts = 22.0,goals = 1.0,assists = 2.0,pk = '0.0',pkatt = 0.0,yellow_card = 9.0,red_card = 0.0)
# Player(clubs_id = 20,first = 'Cristian',last = 'Espinoza',nation = 'ar ARG',position = 'FW,MF',club = 'San Jose Earthquakes',age = 23.0,born = 1995.0,mp = 30.0,starts = 30.0,goals = 2.0,assists = 10.0,pk = '0.0',pkatt = 0.0,yellow_card = 8.0,red_card = 2.0)
# Player(clubs_id = 22,first = 'Roger',last = 'Espinoza',nation = 'hn HON',position = 'MF',club = 'Sporting Kansas City',age = 32.0,born = 1986.0,mp = 16.0,starts = 15.0,goals = 0.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 5.0,red_card = 3.0)
# Player(clubs_id = 6,first = 'Derrick',last = 'Etienne',nation = 'ht HAI',position = 'FW',club = 'FC Cincinnati',age = 22.0,born = 1996.0,mp = 5.0,starts = 2.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 15,first = 'Derrick',last = 'Etienne',nation = 'ht HAI',position = 'FW,MF',club = 'New York Red Bulls',age = 22.0,born = 1996.0,mp = 11.0,starts = 5.0,goals = 1.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 17,first = 'Marco',last = 'Fabián',nation = 'mx MEX',position = 'MF,FW',club = 'Philadelphia Union',age = 29.0,born = 1989.0,mp = 23.0,starts = 15.0,goals = 7.0,assists = 1.0,pk = '2.0',pkatt = 4.0,yellow_card = 5.0,red_card = 1.0)
# Player(clubs_id = 17,first = 'Fabinho',last = 'None',nation = 'br BRA',position = 'DF',club = 'Philadelphia Union',age = 33.0,born = 1985.0,mp = 1.0,starts = 1.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 13,first = 'Diego',last = 'Fagúndez',nation = 'uy URU',position = 'MF,FW',club = 'New England Revolution',age = 23.0,born = 1995.0,mp = 25.0,starts = 13.0,goals = 2.0,assists = 3.0,pk = '0.0',pkatt = 1.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 12,first = 'Rod',last = 'Fanni',nation = 'fr FRA',position = 'DF',club = 'Montreal Impact',age = 37.0,born = 1981.0,mp = 3.0,starts = 3.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 18,first = 'Marco',last = 'Farfan',nation = 'us USA',position = 'DF',club = 'Portland Timbers',age = 20.0,born = 1998.0,mp = 3.0,starts = 3.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 13,first = 'Andrew',last = 'Farrell',nation = 'us USA',position = 'DF',club = 'New England Revolution',age = 26.0,born = 1992.0,mp = 29.0,starts = 29.0,goals = 0.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 7.0,red_card = 0.0)
# Player(clubs_id = 22,first = 'Benny',last = 'Feilhaber',nation = 'us USA',position = 'MF',club = 'Sporting Kansas City',age = 34.0,born = 1985.0,mp = 17.0,starts = 13.0,goals = 2.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 3.0,red_card = 0.0)
# ...
# Player(clubs_id = 14,first = 'Ben',last = 'Sweat',nation = 'us USA',position = 'DF',club = 'New York City FC',age = 27.0,born = 1991.0,mp = 18.0,starts = 13.0,goals = 0.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 0.0)
# Player(clubs_id = 12,first = 'Ballou',last = 'Tabla',nation = 'ca CAN',position = 'MF,FW',club = 'Montreal Impact',age = 19.0,born = 1999.0,mp = 4.0,starts = 1.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 12,first = 'Saphir',last = 'Taïder',nation = 'dz ALG',position = 'MF,FW',club = 'Montreal Impact',age = 26.0,born = 1992.0,mp = 32.0,starts = 31.0,goals = 9.0,assists = 7.0,pk = '5.0',pkatt = 5.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 14,first = 'Ismael',last = 'Tajouri-Shradi',nation = 'ly LBY',position = 'FW,MF',club = 'New York City FC',age = 24.0,born = 1994.0,mp = 19.0,starts = 11.0,goals = 5.0,assists = 3.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 15,first = 'Amro',last = 'Tarek',nation = 'eg EGY',position = 'DF',club = 'New York Red Bulls',age = 26.0,born = 1992.0,mp = 20.0,starts = 19.0,goals = 1.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 6.0,red_card = 1.0)
# Player(clubs_id = 24,first = 'Russell',last = 'Teibert',nation = 'ca CAN',position = 'MF',club = 'Vancouver Whitecaps',age = 26.0,born = 1992.0,mp = 27.0,starts = 26.0,goals = 0.0,assists = 3.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 23,first = 'Ryan',last = 'Telfer',nation = 'tt TRI',position = 'DF',club = 'Toronto FC',age = 24.0,born = 1994.0,mp = 1.0,starts = 0.0,goals = 0.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 20,first = 'Tommy',last = 'Thompson',nation = 'us USA',position = 'DF',club = 'San Jose Earthquakes',age = 23.0,born = 1995.0,mp = 30.0,starts = 28.0,goals = 2.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 7.0,red_card = 1.0)
# Player(clubs_id = 14,first = 'Anton',last = 'Tinnerholm',nation = 'se SWE',position = 'DF',club = 'New York City FC',age = 27.0,born = 1991.0,mp = 30.0,starts = 30.0,goals = 1.0,assists = 7.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 0.0)
# Player(clubs_id = 19,first = 'Donny',last = 'Toia',nation = 'us USA',position = 'DF',club = 'Real Salt Lake',age = 26.0,born = 1992.0,mp = 24.0,starts = 24.0,goals = 1.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 3.0,red_card = 0.0)
# Player(clubs_id = 21,first = 'Nouhou',last = 'Tolo',nation = 'cm CMR',position = 'DF',club = 'Seattle Sounders FC',age = 21.0,born = 1997.0,mp = 22.0,starts = 9.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 5.0,red_card = 0.0)
# Player(clubs_id = 21,first = 'Román',last = 'Torres',nation = 'pa PAN',position = 'DF',club = 'Seattle Sounders FC',age = 32.0,born = 1986.0,mp = 17.0,starts = 12.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 11,first = 'Mason',last = 'Toye',nation = 'us USA',position = 'FW',club = 'Minnesota United',age = 20.0,born = 1998.0,mp = 17.0,starts = 9.0,goals = 6.0,assists = 2.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 1.0)
# Player(clubs_id = 9,first = 'Diedie',last = 'Traoré',nation = 'fr FRA',position = 'DF',club = 'LA Galaxy',age = 20.0,born = 1999.0,mp = 4.0,starts = 3.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 4,first = 'Wil',last = 'Trapp',nation = 'us USA',position = 'MF',club = 'Columbus Crew',age = 26.0,born = 1993.0,mp = 28.0,starts = 26.0,goals = 0.0,assists = 3.0,pk = '0.0',pkatt = 0.0,yellow_card = 5.0,red_card = 0.0)
# Player(clubs_id = 17,first = 'Auston',last = 'Trusty',nation = 'us USA',position = 'DF',club = 'Philadelphia Union',age = 20.0,born = 1998.0,mp = 22.0,starts = 22.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 5.0,red_card = 1.0)
# Player(clubs_id = 18,first = 'Bill',last = 'Tuiloma',nation = 'nz NZL',position = 'DF',club = 'Portland Timbers',age = 23.0,born = 1995.0,mp = 25.0,starts = 21.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 13,first = 'Matt',last = 'Turner',nation = 'us USA',position = 'GK',club = 'New England Revolution',age = 24.0,born = 1994.0,mp = 20.0,starts = 20.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 1.0)
# Player(clubs_id = 7,first = 'Ema',last = 'Twumasi',nation = 'gh GHA',position = 'DF,MF',club = 'FC Dallas',age = 21.0,born = 1997.0,mp = 2.0,starts = 0.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 6,first = 'Przemysław',last = 'Tytoń',nation = 'pl POL',position = 'GK',club = 'FC Cincinnati',age = 32.0,born = 1987.0,mp = 15.0,starts = 15.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 6,first = 'Victor',last = 'Ulloa',nation = 'us USA',position = 'MF',club = 'FC Cincinnati',age = 26.0,born = 1992.0,mp = 26.0,starts = 22.0,goals = 1.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 0.0)
# Player(clubs_id = 12,first = 'Maximiliano',last = 'Urruti',nation = 'ar ARG',position = 'FW',club = 'Montreal Impact',age = 27.0,born = 1991.0,mp = 31.0,starts = 27.0,goals = 4.0,assists = 6.0,pk = '1.0',pkatt = 1.0,yellow_card = 5.0,red_card = 1.0)
# Player(clubs_id = 18,first = 'Zarek',last = 'Valentin',nation = 'us USA',position = 'DF',club = 'Portland Timbers',age = 27.0,born = 1991.0,mp = 21.0,starts = 17.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 5.0,red_card = 0.0)
# Player(clubs_id = 18,first = 'Diego',last = 'Valeri',nation = 'ar ARG',position = 'MF,FW',club = 'Portland Timbers',age = 32.0,born = 1986.0,mp = 31.0,starts = 29.0,goals = 8.0,assists = 8.0,pk = '2.0',pkatt = 4.0,yellow_card = 4.0,red_card = 0.0)
# Player(clubs_id = 15,first = 'Florian',last = 'Valot',nation = 'fr FRA',position = 'MF,FW',club = 'New York Red Bulls',age = 25.0,born = 1993.0,mp = 2.0,starts = 2.0,goals = 0.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 10,first = 'Peter-Lee',last = 'Vassell',nation = 'jm JAM',position = 'MF',club = 'LAFC',age = 20.0,born = 1998.0,mp = 6.0,starts = 2.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 1,first = 'Brandon',last = 'Vazquez',nation = 'us USA',position = 'FW',club = 'Atlanta United',age = 20.0,born = 1998.0,mp = 11.0,starts = 7.0,goals = 2.0,assists = 1.0,pk = '1.0',pkatt = 1.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 10,first = 'Carlos',last = 'Vela',nation = 'mx MEX',position = 'FW',club = 'LAFC',age = 29.0,born = 1989.0,mp = 31.0,starts = 31.0,goals = 34.0,assists = 10.0,pk = '9.0',pkatt = 11.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 24,first = 'Lucas',last = 'Venuto',nation = 'br BRA',position = 'FW',club = 'Vancouver Whitecaps',age = 24.0,born = 1995.0,mp = 22.0,starts = 12.0,goals = 3.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 3.0,red_card = 0.0)
# Player(clubs_id = 8,first = 'Matías',last = 'Vera',nation = 'ar ARG',position = 'MF',club = 'Houston Dynamo',age = 23.0,born = 1995.0,mp = 30.0,starts = 30.0,goals = 0.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 10.0,red_card = 1.0)
# Player(clubs_id = 18,first = 'Jorge',last = 'Villafaña',nation = 'us USA',position = 'DF',club = 'Portland Timbers',age = 29.0,born = 1989.0,mp = 23.0,starts = 22.0,goals = 0.0,assists = 4.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 1,first = 'Héctor',last = 'Villalba',nation = 'py PAR',position = 'FW,MF',club = 'Atlanta United',age = 24.0,born = 1994.0,mp = 20.0,starts = 10.0,goals = 1.0,assists = 3.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 3,first = 'Sam',last = 'Vines',nation = 'us USA',position = 'DF',club = 'Colorado Rapids',age = 19.0,born = 1999.0,mp = 26.0,starts = 23.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 17,first = 'Kai',last = 'Wagner',nation = 'de GER',position = 'DF',club = 'Philadelphia Union',age = 21.0,born = 1997.0,mp = 30.0,starts = 30.0,goals = 0.0,assists = 6.0,pk = '0.0',pkatt = 0.0,yellow_card = 6.0,red_card = 1.0)
# Player(clubs_id = 22,first = 'Rodney',last = 'Wallace',nation = 'cr CRC',position = 'DF',club = 'Sporting Kansas City',age = 30.0,born = 1988.0,mp = 1.0,starts = 1.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 5,first = 'Akeem',last = 'Ward',nation = 'us USA',position = 'DF',club = 'DC United',age = 23.0,born = 1996.0,mp = 1.0,starts = 1.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 6,first = 'Kendall',last = 'Waston',nation = 'cr CRC',position = 'DF',club = 'FC Cincinnati',age = 31.0,born = 1988.0,mp = 25.0,starts = 24.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 10.0,red_card = 1.0)
# Player(clubs_id = 23,first = 'Quentin',last = 'Westberg',nation = 'us USA',position = 'GK',club = 'Toronto FC',age = 32.0,born = 1986.0,mp = 28.0,starts = 28.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 15,first = 'Brian',last = 'White',nation = 'us USA',position = 'FW',club = 'New York Red Bulls',age = 22.0,born = 1996.0,mp = 19.0,starts = 17.0,goals = 8.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 4,first = 'JJ',last = 'Williams',nation = 'us USA',position = 'FW',club = 'Columbus Crew',age = 21.0,born = 1998.0,mp = 7.0,starts = 3.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 4,first = 'Josh',last = 'Williams',nation = 'us USA',position = 'DF',club = 'Columbus Crew',age = 30.0,born = 1988.0,mp = 16.0,starts = 15.0,goals = 2.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 1,first = 'Romario',last = 'Williams',nation = 'jm JAM',position = 'FW,DF',club = 'Atlanta United',age = 24.0,born = 1994.0,mp = 2.0,starts = 0.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 4,first = 'Romario',last = 'Williams',nation = 'jm JAM',position = 'FW,MF',club = 'Columbus Crew',age = 24.0,born = 1994.0,mp = 7.0,starts = 1.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 18,first = 'Eryk',last = 'Williamson',nation = 'us USA',position = 'MF,FW',club = 'Portland Timbers',age = 21.0,born = 1997.0,mp = 7.0,starts = 3.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 8,first = 'Joe',last = 'Willis',nation = 'us USA',position = 'GK',club = 'Houston Dynamo',age = 30.0,born = 1988.0,mp = 27.0,starts = 27.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 3,first = 'Danny',last = 'Wilson',nation = 'sco SCO',position = 'MF,DF',club = 'Colorado Rapids',age = 27.0,born = 1991.0,mp = 20.0,starts = 15.0,goals = 2.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 0.0)
# Player(clubs_id = 21,first = 'Henry',last = 'Wingo',nation = 'us USA',position = 'FW',club = 'Seattle Sounders FC',age = 23.0,born = 1995.0,mp = 6.0,starts = 2.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 20,first = 'Chris',last = 'Wondolowski',nation = 'us USA',position = 'FW',club = 'San Jose Earthquakes',age = 36.0,born = 1983.0,mp = 32.0,starts = 24.0,goals = 15.0,assists = 2.0,pk = '0.0',pkatt = 0.0,yellow_card = 3.0,red_card = 1.0)
# Player(clubs_id = 17,first = 'Andrew',last = 'Wooten',nation = 'us USA',position = 'FW',club = 'Philadelphia Union',age = 29.0,born = 1989.0,mp = 7.0,starts = 4.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 13,first = 'Brian',last = 'Wright',nation = 'ca CAN',position = 'FW,MF',club = 'New England Revolution',age = 23.0,born = 1995.0,mp = 2.0,starts = 0.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 15,first = 'Bradley',last = 'Wright-Phillips',nation = 'eng ENG',position = 'FW',club = 'New York Red Bulls',age = 33.0,born = 1985.0,mp = 24.0,starts = 9.0,goals = 2.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 3.0,red_card = 0.0)
# Player(clubs_id = 3,first = 'Deklan',last = 'Wynne',nation = 'nz NZL',position = 'DF',club = 'Colorado Rapids',age = 23.0,born = 1995.0,mp = 11.0,starts = 11.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 5,first = 'Griffin',last = 'Yow',nation = 'us USA',position = 'FW',club = 'DC United',age = 16.0,born = 2002.0,mp = 2.0,starts = 1.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 20,first = 'Jackson',last = 'Yueill',nation = 'us USA',position = 'MF',club = 'San Jose Earthquakes',age = 21.0,born = 1997.0,mp = 32.0,starts = 29.0,goals = 3.0,assists = 4.0,pk = '0.0',pkatt = 0.0,yellow_card = 2.0,red_card = 0.0)
# Player(clubs_id = 13,first = 'Wilfried',last = 'Zahibo',nation = 'cf CTA',position = 'MF',club = 'New England Revolution',age = 25.0,born = 1993.0,mp = 24.0,starts = 18.0,goals = 1.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 8.0,red_card = 1.0)
# Player(clubs_id = 18,first = 'Renzo',last = 'Zambrano',nation = 've VEN',position = 'MF',club = 'Portland Timbers',age = 24.0,born = 1994.0,mp = 10.0,starts = 9.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 4.0,red_card = 1.0)
# Player(clubs_id = 4,first = 'Gyasi',last = 'Zardes',nation = 'us USA',position = 'FW',club = 'Columbus Crew',age = 27.0,born = 1991.0,mp = 28.0,starts = 28.0,goals = 13.0,assists = 2.0,pk = '3.0',pkatt = 3.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 23,first = 'Eriq',last = 'Zavaleta',nation = 'us USA',position = 'DF',club = 'Toronto FC',age = 26.0,born = 1992.0,mp = 16.0,starts = 11.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 3.0,red_card = 1.0)
# Player(clubs_id = 22,first = 'Gedion',last = 'Zelalem',nation = 'us USA',position = 'MF',club = 'Sporting Kansas City',age = 22.0,born = 1997.0,mp = 9.0,starts = 5.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 1.0,red_card = 0.0)
# Player(clubs_id = 10,first = 'Rodolfo',last = 'Zelaya',nation = 'sv SLV',position = 'FW',club = 'LAFC',age = 30.0,born = 1988.0,mp = 4.0,starts = 1.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 22,first = 'Adrian',last = 'Zendejas',nation = 'mx MEX',position = 'GK',club = 'Sporting Kansas City',age = 23.0,born = 1995.0,mp = 1.0,starts = 1.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 7,first = 'Reto',last = 'Ziegler',nation = 'ch SUI',position = 'DF',club = 'FC Dallas',age = 33.0,born = 1986.0,mp = 32.0,starts = 32.0,goals = 5.0,assists = 0.0,pk = '4.0',pkatt = 5.0,yellow_card = 6.0,red_card = 0.0)
# Player(clubs_id = 10,first = 'Walker',last = 'Zimmerman',nation = 'us USA',position = 'DF',club = 'LAFC',age = 25.0,born = 1993.0,mp = 25.0,starts = 25.0,goals = 1.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 8.0,red_card = 1.0)
# Player(clubs_id = 9,first = 'Ethan',last = 'Zubak',nation = 'us USA',position = 'MF,FW',club = 'LA Galaxy',age = 20.0,born = 1998.0,mp = 3.0,starts = 0.0,goals = 0.0,assists = 0.0,pk = '0.0',pkatt = 0.0,yellow_card = 0.0,red_card = 0.0)
# Player(clubs_id = 22,first = 'Graham',last = 'Zusi',nation = 'us USA',position = 'DF',club = 'Sporting Kansas City',age = 32.0,born = 1986.0,mp = 27.0,starts = 26.0,goals = 0.0,assists = 1.0,pk = '0.0',pkatt = 0.0,yellow_card = 5.0,red_card = 0.0)

# %%
# Commit all of the tables at once then close: 
session.commit()
